# %% [markdown]
# <div class="fig" style="font-size: 10pt; font-family: monospace; white-space: pre; color: #000000; font-style: normal; font-variant-ligatures: normal; font-variant-caps: normal; font-weight: 400; letter-spacing: normal; orphans: 2; text-align: start; text-indent: 0px; text-transform: none; widows: 2; word-spacing: 0px; -webkit-text-stroke-width: 0px; background-color: #ffffff; text-decoration-thickness: initial; text-decoration-style: initial; text-decoration-color: initial;">
# <pre id="taag_font_Big" class="fig" style="font-size: 12pt; font-family: monospace; white-space: pre; margin-top: 15px; margin-bottom: 15px; float: left;" contenteditable="true"><strong>  ______ _____                          ______                  __  __            _
#  |  ____|  __ \   /\                   |  ____|                |  \/  |          | |
#  | |__  | |  | | /  \      ___  _ __   | |__  _   _ _ __ ___   | \  / | __ _ _ __| |_
#  |  __| | |  | |/ /\ \    / _ \| '_ \  |  __|| | | | '__/ _ \  | |\/| |/ _` | '__| __|
#  | |____| |__| / ____ \  | (_) | | | | | |___| |_| | | | (_) | | |  | | (_| | |  | |_
#  |______|_____/_/    \_\  \___/|_| |_| |______\__,_|_|  \___/  |_|  |_|\__,_|_|   \__|
#
# <p>&nbsp;</p>
#
# <p> &nbsp<strong>:Presented by Venukumar M</strong></p>

# %% [markdown]
# <h2>About Euromart:</h2>
# <p>Euromart is a retail store having its chain of operating stores across Europe in 15 counties</p>
# <p>They offer variety of product categories to the customers</p>
# <p>Euromart wants to leverage its transactions data to improve its business</p>
# <p>Euromart have reached Certisured for their requirements</p>
# <p>&nbsp;</p>

# %% [markdown]
# <!DOCTYPE html>
# <html lang="en">
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#
#   <style>
#     .box {
#       display: inline-block;
#       margin: 10px;
#       padding: 10px;
#       border: 1px solid black;
#       border-radius: 5px;
#       text-align: center;
#     }
#     .arrow {
#       font-size: 20px;
#       font-weight: bold;
#     }
#   </style>
# </head>
# <body>
#   <h1>Euromart EDA Analysis Pipeline</h1>

# %% [markdown]
#   <div class="box">
#       <span style='font-size:20px;'>&#49;</span>
#     <b>Data Acquisition and Objective</b>
#     <ul>
#       <li>Obtain Euromart data (CSV, Excel)</li>
#       <li>Get problem statement from Euromart</li>
#       <li>Choose tools/environment & programming language</li>
#     </ul>
#     <div <span style='font-size:30px;'>&#8681;</span></div>
#   </div>
#    <div class="box">
#       <span style='font-size:20px;'>&#50</span>
#     <b>Data Loading/Reading</b>
#     <ul>
#       <li>Load data in MySQL</b> (Remove duplicates)</li>
#       <li>Load data in  Jupyter Notebook</b> (To perform further analysis)</li>
#     </ul>
#     <div <span style='font-size:30px;'>&#8681;</span></div>
#   </div>
#   <div class="box">
#       <span style='font-size:20px;'>&#51</span>
#     <b>Familiarize with Data & Identify Target Variable</b>
#     <ul>
#       <li>Explore data (column names, data types)</li>
#       <li>Identify target variable based on objective</li>
#     </ul>
#     <div <span style='font-size:30px;'>&#8681;</span></div>
#   </div>
#   <div class="box">
#       <span style='font-size:20px;'>&#52</span>
#     <b>Data Preparation & Transformation</b>
#     <ul>
#       <li><b>Data Cleaning</b>
#         <ul>
#           <li>Handle missing values (imputation, deletion)</li>
#           <li>Remove unwanted data (if present)</li>
#           <li>Format data types (numerical & categorical)</li>
#         </ul>
#       </li>
#       <li><b>Feature Engineering</b> (Create new features)</li>
#     </ul>
#     <div <span style='font-size:30px;'>&#8681;</span></div>
#   </div>
#   <div class="box">
#       <span style='font-size:20px;'>&#53</span>
#     <b>Data Analysis & Visualization</b>
#     <ul>
#       <li><b>Univariate Analysis</b>
#         <ul>
#           <li>Numerical variables (mean, median, stddev)</li>
#           <li>Categorical variables (distribution)</li>
#         </ul>
#       </li>
#       <li><b>Bivariate & Multivariate Analysis</b> (Identify patterns)</li>
#       <li><b>Visualization</b> (Charts: pie, boxplot, histogram, heatmap)</li>
#     </ul>
#     <div <span style='font-size:30px;'>&#8681;</span></div>
#   </div>
#   <div class="box">
#       <span style='font-size:20px;'>&#54</span>
#     <b>Conclusion/Suggestions & Documentation</b>
#     <ul>
#       <li>Summarize key observations & insights</li>
#       <li>Provide suggestions for Euromart & document findings</li>
#     </ul>
#   </div>
# </body>
# </html>
# <p>&nbsp;</p>

# %% [markdown]
# **Table of contents**<a id='toc0_'></a>
# - [1 Data Acquisition and Objective ](#toc1_)
# - [2 Data Loading/reading ](#toc2_)
# - [3 Familiarize with Data & Identifying the Target Variable ](#toc3_)
# - [4 Data Preparation & Transformation ](#toc4_)
# - [5 Data Analysis & Visualization ](#toc5_)
# - [6 Summary  and Suggestions](#toc6_)
#
# <!-- vscode-jupyter-toc-config
# 	numbering=false
# 	anchor=true
# 	flat=false
# 	minLevel=1
# 	maxLevel=6
# 	/vscode-jupyter-toc-config -->
# <!-- THIS CELL WILL BE REPLACED ON TOC UPDATE. DO NOT WRITE YOUR TEXT IN THIS CELL -->

# %% [markdown]
# <p>&nbsp;</p>

# %% [markdown]
# # <a id='toc1_'></a>[1 Data Acquisition and Objective ](#toc0_)

# %% [markdown]
# <h2>Euromart data received in <strong>CSV Format</strong> </h2>

# %% [markdown]
# <h2><strong>1.1 Problem Statement:</strong></h2>

# %% [markdown]
# <p><strong>Problem Statement:</strong> Identify <strong>key factors influencing sales and profitability</strong> in different regions, product categories, and transaction types to optimize operations and pricing strategies.</p>
# <p><strong>Purpose:</strong></p>
# <ul>
# <li><strong>Identifying Top Performers:</strong> Pinpoint regions, product categories, and transaction types driving highest sales &amp; profitability to replicate successful strategies.</li>
# <li><strong>Understanding Challenges:</strong> Address operational inefficiencies and customer engagement issues in underperforming areas.</li>
# <li><strong>Optimizing Discounts &amp; Shipping Modes:</strong> Analyze impact of discounts and shipping modes to refine pricing strategies and logistics for max profitability.</li>
# <li><strong>Leveraging Customer Feedback:</strong> Use customer feedback to enhance product offerings and improve overall business performance.</li>
# <li><strong>Improving Product Mix:</strong> Identify top-selling products and customer preferences to optimize our product mix.</li>
# </ul>
# <p>&nbsp;</p>

# %% [markdown]
# <h2><strong>1.2 Tools and platforms used in project<strong></h2>

# %% [markdown]
# <p><strong>Why Python and MYSQL?</strong></p>
# <p>Python is a high level and open source programming language for mathematical computations and basic visualizations. SQL is the most common language for querying relational databases. Also, Python and SQL are most sought after programming languages in the India today</p>
# <p><strong>Platforms used:</strong></p>
# <ul>
# <li>Jupyter notebook &ndash; it is a web-based application for running code and queries in Python</li>
# <li>Visual Studio Code (VS Code) &ndash; it is a free, opensource code editor which supports multiple programming languages</li>
# <li>MySQL - MySQL workbench by Oracle is widely used open-source RDBMS, it is cross-platform support</li>
# </ul>
# <p><strong>Versions of platform</strong></p>
# <ul>
# <li>Jupyter notebook - 7.1.3</li>
# <li>Visual Studio Code - 1.89.1</li>
# <li>MySQL Workbench - 8.0.36</li>
# <li>Python version - 3.12.2</li>
# </ul>
# <p>Note: Code format is IPYNB file.It is a text-based file used by Jupyter Notebook (VS Code also supports IPYNB with Jupyter extension) </p>
# <p>&nbsp;</p>

# %% [markdown]
# # <a id='toc2_'></a>[2 Data Loading/reading ](#toc0_)

# %% [markdown]
# <h2><strong>2.1 Load Data in MySQL<strong></h2>
# <p><span style="color: #808080;"> We need to import necessary libraries for performing loading, connecting with SQL and doing analysis</span></p>

# %% [markdown]
# <h3><span style="color: #808080;">2.1.1 Import Necessary Library</span></h3>
# <p data-sourcepos="3:1-3:41"><span style="color: #ffcc00;">Code Explanation:</span></p>
# <ul>
# <li ><span style="color: #808080;">mysql.connector: Library offers connectivity to MySQL server to query from database</span></li>
# <li ><span style="color: #808080;">numpy (np): Provides efficient numerical computation tools.</span></li>
# <li ><span style="color: #808080;">pandas (pd): Offers data manipulation and analysis structures (DataFrames, Series).</span></li>
# <li ><span style="color: #808080;">seaborn (sns): Creates informative statistical data visualizations based on Matplotlib.</span></li>
# <li ><span style="color: #808080;">matplotlib.pyplot (plt): Enables various plot creations for data visualization.</span></li>
# <li ><span style="color: #808080;">%matplotlib inline (Jupyter Notebook specific): Displays plots within the notebook.</span></li>
# <li ><span style="color: #808080;">warnings (with warnings.filterwarnings("ignore")): Suppresses warnings.</span></li>
# </ul>

# %%
import mysql.connector
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# <h3><span style="color: #808080;">2.1.2 Establish a connection to the euro_mart database using MySQL Connector</span></h3>
# <p data-sourcepos="3:1-3:41"><span style="color: #ffcc00;">Code Explanation:</span></p>
# <ul>
# <li ><span style="color: #808080;">Initialize a connection to a MySQL database named euro_mart on the local machine (localhost).</span></li>
# <li ><span style="color: #808080;">Uses credentials with username and password</span></li>

# %%
Connection = mysql.connector.connect(
  host="localhost",               #hostname
  user="root",                    #the user who has privilege to the db
  passwd="root",                  #password for user
  database="euro_mart",           #database name
)

# %% [markdown]
# <h2><strong>2.2 Load Data (Jupyter Notebook or VS Code)<strong></h2>
# <p><span style="color: #808080;"> The data is loaded to Jupyter Notebook from MySQL, this actively removes all the null values in rows by default, which is make data one step closer for it to be cleaned</span></p>

# %% [markdown]
# <h3><span style="color: #808080;">2.2.1 Retrieve data from a MySQL database table and load it into a pandas DataFrame for further analysis in Jupyter Notebook</span></h3>
# <p data-sourcepos="3:1-3:41"><span style="color: #ffcc00;">Code Explanation:</span></p>
# <ul>
# <li ><span style="color: #808080;">query1 = "Use euro_mart; establishes connection with correct database</span></li>
# <li ><span style="color: #808080;">query = "select * from euromart_table; selects all columns (*) from the table named euromart_table</span></li>
# <li ><span style="color: #808080;">df = pd.read_sql(query, Connection); execute the defined query (query) on the established connection (Connection). The result is stored in a pandas DataFrame named df</span></li>

# %%
query1 = "Use euro_mart;" # establish connection with correct database
query = "select * from euromart_table;" #select all columsn in database/table

df = pd.read_sql(query,Connection) #Execute query and store in dataframe df

# %% [markdown]
# # <a id='toc3_'></a>[3 Familiarize with Data & Identifying the Target Variable ](#toc0_)

# %% [markdown]
# <h2><strong>3.1 Explore the provided data (column names, data types)<strong></h2>
# <p><span style="color: #808080;"> We need to understand the data before cleaning the data and also cross verify if all the required data are provided by Euromart</span></p>

# %% [markdown]
# <h3><span style="color: #808080;">3.1.1 Overview of data</span></h3>
# <p data-sourcepos="3:1-3:41"><span style="color: #ffcc00;">Code Explanation:</span></p>
# <ul>
# <li ><span style="color: #808080;">df.head(); Let's see the data by displaying the first 5 rows</span></li>
# <li ><span style="color: #808080;">df.tail(); Let's see the last 5 rows</span></li>
# <li ><span style="color: #808080;">df.shape is used to get the dimensions (number of rows and columns) of data</span></li>
# <li ><span style="color: #808080;">df.size is used to get the total number of elements in a pandas</span></li>
# <li ><span style="color: #808080;">df.info() - used to display concise information about</span></li>
# </ul>
#
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Structured Data: Data provided is in table format</span></li>
# <li ><span style="color: #808080;">Dimensions (17 Columns x 8047 Rows, and has 1,36,799 elements in it) of the DataFrame or data</span></li>
# <li ><span style="color: #808080;">Column Data Types: Observed mix of data type of each column (e.g., object, float, int, etc.)</span></li>
# <li ><span style="color: #808080;">Also note that all categorical/qualitative variables are Nominal in nature (it has no specific orders)</span></li>
# <li ><span style="color: #808080;">Non-Null Counts (no Null values observed) in each column.</span></li>
# <li ><span style="color: #808080;">Memory Usage: An estimate of the memory usage is 1.0+ MB (Further, we will optimize the memory usage by modifying the data types)</span></li>
# </ul>

# %%
df.head()
# Out:
#           Order ID Order Date     Customer Name         Country  \
# 0  BN-2011-7407039   1/1/2011        Ruby Patel          Sweden
# 1  AZ-2011-9050313   1/3/2011    Summer Hayward  United Kingdom
# 2  AZ-2011-6674300   1/4/2011  Devin Huddleston          France
# 3  BN-2011-2819714   1/4/2011       Mary Parker  United Kingdom
# 4  BN-2011-2819714   1/4/2011       Mary Parker  United Kingdom
#
#                   State        City   Region      Segment     Ship Mode  \
# 0             Stockholm   Stockholm    North  Home Office  Economy Plus
# 1               England   Southport    North     Consumer       Economy
# 2  Auvergne-Rhône-Alpes     Valence  Central     Consumer       Economy
# 3               England  Birmingham    North    Corporate       Economy
# 4               England  Birmingham    North    Corporate       Economy
#
#           Category Sub-Category                           Product Name  \
# 0  Office Supplies        Paper            Enermax Note Cards, Premium
# ...

# %%
df.tail()
# Out:
#              Order ID  Order Date    Customer Name         Country  \
# 8042   AZ-2014-766953  12/31/2014     Jose Gambino  United Kingdom
# 8043  BN-2014-4140795  12/31/2014  Daniel Hamilton     Netherlands
# 8044  BN-2014-4140795  12/31/2014  Daniel Hamilton     Netherlands
# 8045  BN-2014-4140795  12/31/2014  Daniel Hamilton     Netherlands
# 8046   AZ-2014-766953  12/31/2014     Jose Gambino  United Kingdom
#
#               State        City   Region      Segment     Ship Mode  \
# 8042        England  Maidenhead    North    Corporate       Economy
# 8043  North Brabant   Eindhoven  Central  Home Office  Economy Plus
# 8044  North Brabant   Eindhoven  Central  Home Office  Economy Plus
# 8045  North Brabant   Eindhoven  Central  Home Office  Economy Plus
# 8046        England  Maidenhead    North    Corporate       Economy
#
#              Category Sub-Category                          Product Name  \
# 8042        Furniture    Bookcases  Ikea Stackable Bookrack, Traditional
# ...

# %%
df.shape
# Out:
# (8047, 17)

# %%
df.size
# Out:
# 136799

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8047 entries, 0 to 8046
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       8047 non-null   object
#  1   Order Date     8047 non-null   object
#  2   Customer Name  8047 non-null   object
#  3   Country        8047 non-null   object
#  4   State          8047 non-null   object
#  5   City           8047 non-null   object
#  6   Region         8047 non-null   object
#  7   Segment        8047 non-null   object
#  8   Ship Mode      8047 non-null   object
#  9   Category       8047 non-null   object
#  10  Sub-Category   8047 non-null   object
#  11  Product Name   8047 non-null   object
#  12  Discount       8047 non-null   float64
#  13  Sales          8047 non-null   int64
#  14  Profit         8047 non-null   int64
#  15  Quantity       8047 non-null   int64
#  16  Feedback?      8047 non-null   object
# ...

# %% [markdown]
# <h2><strong>3.2 Identify target variable based on objective<strong></h2>
# <p><span style="color: #808080;">Once we are clear with data, for further analysis we have to fix target variable and feature variables for performing EDA</span></p>

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Fix Target value:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">From the data and from problem statement we understand that<strong> target variables are Profit and Sales</strong></span></li>
# <li ><span style="color: #808080;">Feature variables are remaining columns like Country, State, City, Region, etc..,</span></li>
# <li ><span style="color: #808080;">Now we are clear to perform data cleaning and EDA analaysis</span></li>
# </ul>

# %% [markdown]
# # <a id='toc4_'></a>[4 Data Preparation & Transformation ](#toc0_)

# %% [markdown]
# <h2><strong>4.1 Data Cleaning</strong></h2>
# <p><span style="color: #808080;"> We need to perform steps mentioned below to clean data</span></p>
# <ul>
# <li ><strong><span style="color: #808080;">Steps involved in handling missing values (imputation, deletion)</strong></span></li>
#     <ul>
#         <li ><span style="color: #808080;">We accept missing values if data is small in dimension</span></li>
#         <li ><span style="color: #808080;">We delete missing values if:</span></li>
#     <ul>
#             <li ><span style="color: #808080;">When more than 80% of data is missing/null values</span></li>
#             <li ><span style="color: #808080;">When the percentage of missing values are very small, deleting will have minimal effect on analysis</span></li>
#     </ul>
#         <li ><span style="color: #808080;">Replacing the missing values by imputation</span></li>
#     <ul>
#             <li ><span style="color: #808080;">Imputation: We replace the missing values by Mean, Median or Mode of the variable or perform fill null values(fillna method) with the desired value</span></li>
#     </ul>
#     </ul>
#
# <li ><strong><span style="color: #808080;">Data Reduction: Remove unwanted data (if present) which are not required for analysis</strong></span></li>
#     <ul>
#             <li ><span style="color: #808080;">Delete unwanted columns</span></li>
#             <li ><span style="color: #808080;">Delete duplicate rows</span></li>
#     </ul>
# <li ><strong><span style="color: #808080;">Format data types (numerical & categorical variables)</strong></span></li>
# <li ><strong><span style="color: #808080;">Outlier detection and handling (we ignore this step because outliers are valid in our case)</strong></span></li>
#     <ul>
#             <li ><span style="color: #808080;">When data has extreme values that could effect our analysis, we either replace them with Mean or Median or Mode values or we accept the outliers</span></li>
#                     <li ><span style="color: #808080;">We identify the outliers by plotting the Box plot</span></li>
#     </ul>
# </ul>

# %% [markdown]
# <h3><span style="color: #808080;">4.1.1 Handle missing values (imputation or deletion)</span></h3>
# <p data-sourcepos="3:1-3:41"><span style="color: #ffcc00;">Code Explanation:</span></p>
# <ul>
# <li ><span style="color: #808080;">df.isnull().sum() - Gives sum of all null values in each column</span></li>
# <li ><span style="color: #808080;">df.notnull().sum() - Gives sum of all not null unique values in each column</span></li>
# </ul>
#
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Data has no null values, so no need to perform process to handle missing values</span></li>
# </ul>

# %%
df.isnull().sum()
# Out:
# Order ID         0
# Order Date       0
# Customer Name    0
# Country          0
# State            0
# City             0
# Region           0
# Segment          0
# Ship Mode        0
# Category         0
# Sub-Category     0
# Product Name     0
# Discount         0
# Sales            0
# Profit           0
# Quantity         0
# Feedback?        0
# dtype: int64

# %%
df.notnull().sum()
# Out:
# Order ID         8047
# Order Date       8047
# Customer Name    8047
# Country          8047
# State            8047
# City             8047
# Region           8047
# Segment          8047
# Ship Mode        8047
# Category         8047
# Sub-Category     8047
# Product Name     8047
# Discount         8047
# Sales            8047
# Profit           8047
# Quantity         8047
# Feedback?        8047
# dtype: int64

# %% [markdown]
# <h3><span style="color: #808080;">4.1.2 Data Reduction: Remove unwanted columns or rows</span></h3>
# <li ><span style="color: #808080;">There are no unwanted columns to delete, so we can check for duplicated rows and delete the duplicates</span></li>
# <p data-sourcepos="3:1-3:41"><span style="color: #ffcc00;">Code Explanation:</span></p>
# <ul>
# <li ><span style="color: #808080;">df.duplicated().sum(); This shows number of duplicated rows</span></li>
# <li ><span style="color: #808080;">df = df.drop_duplicates(); This removes duplicated rows</span></li>
# </ul>
#
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">It is noted that there are 2 rows which are repeated. We have removed duplicated rows</span></li>
# </ul>

# %%
df.duplicated().sum()
# Out:
# 2

# %%
df = df.drop_duplicates()

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# <h3><span style="color: #808080;">4.1.3 Format data types (numerical & categorical)</span></h3>
# <p><span style="color: #808080;"> We need to format columns, that will ease data analysis, below steps are performed to the required format for analysis  </span></p>
# <ul>
# <li ><span style="color: #808080;">Rename of columns - To keep columns descriptive as well as simple</span></li>
# <li ><span style="color: #808080;">Change data types - We change data type to keep consistency and also for memory optimization</span></li>
# </ul>

# %% [markdown]
# <h3><span style="color: #808080;">4.1.4 Rename of columns</span></h3>
# <p data-sourcepos="3:1-3:41"><span style="color: #ffcc00;">Code Explanation:</span></p>
# <ul>
# <li ><span style="color: #808080;">df.rename(columns={'Feedback?': 'Feedback'}, inplace=True) - This renames the column name, Inplace=True; this permanently alters the name </span></li>
# <li ><span style="color: #808080;">df.columns; This display columns for cross verifying that renaming step is performed</span></li>
# </ul>
#
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Feedback column is renamed by removing special character in column</span></li>
# </ul>

# %%
df.rename(columns={'Feedback?': 'Feedback'}, inplace=True)
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'Country', 'State', 'City',
#        'Region', 'Segment', 'Ship Mode', 'Category', 'Sub-Category',
#        'Product Name', 'Discount', 'Sales', 'Profit', 'Quantity', 'Feedback'],
#       dtype='object')

# %% [markdown]
# <h3><span style="color: #808080;">4.1.5 Change data types of columns and Memory optimization</span></h3>
# <p data-sourcepos="3:1-3:41"><span style="color: #ffcc00;">Code Explanation:</span></p>
# <ul>
# <li ><span style="color: #808080;">df.info(); We can see the column data type </span></li>
# <li ><span style="color: #808080;">cols_to_convert = df.columns[2:12]; Select 3rd column to 12 column </span></li>
# <li ><span style="color: #808080;">df['Order Date'] = pd.to_datetime(df['Order Date']); Convert the "Order Date" column to datetime data type </span></li>
#
# </ul>
#
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">We are converting all columns with object data type to category and converted order date column to date-time format</span></li>
# <li ><span style="color: #808080;">Now memory usage is reduced from 1.0+ MB to 700+ KB. With this we achieved memory optimization for space complexity</span></li>
# </ul>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8045 entries, 0 to 8046
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       8045 non-null   object
#  1   Order Date     8045 non-null   object
#  2   Customer Name  8045 non-null   object
#  3   Country        8045 non-null   object
#  4   State          8045 non-null   object
#  5   City           8045 non-null   object
#  6   Region         8045 non-null   object
#  7   Segment        8045 non-null   object
#  8   Ship Mode      8045 non-null   object
#  9   Category       8045 non-null   object
#  10  Sub-Category   8045 non-null   object
#  11  Product Name   8045 non-null   object
#  12  Discount       8045 non-null   float64
#  13  Sales          8045 non-null   int64
#  14  Profit         8045 non-null   int64
#  15  Quantity       8045 non-null   int64
#  16  Feedback       8045 non-null   object
# ...

# %%
# Select the 3rd to 12th columns
cols_to_convert = df.columns[2:12]

# Convert the data type of the selected columns
df[cols_to_convert] = df[cols_to_convert].astype("category")

# Convert the "Order Date" column to datetime data type
df['Order Date'] = pd.to_datetime(df['Order Date'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8045 entries, 0 to 8046
# Data columns (total 17 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Order ID       8045 non-null   object
#  1   Order Date     8045 non-null   datetime64[ns]
#  2   Customer Name  8045 non-null   category
#  3   Country        8045 non-null   category
#  4   State          8045 non-null   category
#  5   City           8045 non-null   category
#  6   Region         8045 non-null   category
#  7   Segment        8045 non-null   category
#  8   Ship Mode      8045 non-null   category
#  9   Category       8045 non-null   category
#  10  Sub-Category   8045 non-null   category
#  11  Product Name   8045 non-null   category
#  12  Discount       8045 non-null   float64
#  13  Sales          8045 non-null   int64
#  14  Profit         8045 non-null   int64
#  15  Quantity       8045 non-null   int64
#  16  Feedback       8045 non-null   object
# ...

# %% [markdown]
# <h2><strong>4.2 Feature Engineering (Create new features/variables)</strong></h2>
# <p><span style="color: #808080;"> We derive new variables or features by combining multiple columns or derive new features by performing calculation </span></p>
#
# <p><span style="color: #808080;"> Here we need to create new columns for easier analysis</span></p>
# <ul>
# <li ><span style="color: #808080;">Create new columns by extracting date, month, year and generate new columns like Quarter and Weeks</span></li>
# <li ><span style="color: #808080;">Create new columns by calculating Total sales, Total profit, Profit margin and discount percentage</span></li>
# </ul>

# %% [markdown]
# <h3><span style="color: #808080;">4.2.1 Create new features</span></h3>
# <p data-sourcepos="3:1-3:41"><span style="color: #ffcc00;">Code Explanation:</span></p>
# <ul>
# <li ><span style="color: #808080;">df['Year'] = df['Order Date'].dt.year; Extract and create a new column named Year form Order date column</span></li>
#
# <li ><span style="color: #808080;">df['Month'] = df['Order Date'].dt.month; Extract and create a new column named Date form Order date column </span></li>
#
# <li ><span style="color: #808080;">df['Day'] = df['Order Date'].dt.day; Extract and create a new column named Year Day Order date column</span></li>
#
# <li ><span style="color: #808080;">quarter_dict = {1 : 'Q1', 2 : 'Q1', 3 : 'Q1',4 : 'Q2'......}; this defines a dictionary which maps month to corresponding Quarters</span></li>
#
# <li ><span style="color: #808080;">df['Quarter'] = df['Month'].map(quarter_dict);  this uses the map method to apply the quarter_dict dictionary to the "Quarter" column</span></li>
#
# <li ><span style="color: #808080;">week_dict = {1: 'W1', 2: 'W1', 3: 'W1'......};  this defines a dictionary which maps days to corresponding Week</span></li>
#
# <li ><span style="color: #808080;">df['Week'] = None; Initialize 'Week' column with None values</span></li>
#
# <li ><span style="color: #808080;">df['Week'] = df['Day'].map(week_dict); this uses the map method to apply the week_dict dictionary to the "Week" column</span></li>
#
# <li ><span style="color: #808080;">df.info; gives list of all columns and its details for cross verifying on feature engineering</span></li>
#
# <li ><span style="color: #808080;">df['Order Size'] = df.groupby('Order ID')['Product Name']; Create a new column based on number of times order ID is reapeated</span></li>
# </ul>
#
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">We are set with feature engineering by creating multiple columns for easier analysis</span></li>
#
# </ul>

# %%
# The year and month of the order date.
df['Year'] = df['Order Date'].dt.year
df['Year'] = df['Year'].astype("category")
df['Month'] = df['Order Date'].dt.month
df['Month'] = df['Month'].astype("category")
df['Day'] = df['Order Date'].dt.day
df['Day'] = df['Day'].astype("category")

# Creating a new colum that has Quarters in the year
quarter_dict = {
    1 : 'Q1', 2 : 'Q1', 3 : 'Q1',
    4 : 'Q2', 5 : 'Q2', 6 : 'Q2',
    7 : 'Q3', 8 : 'Q3', 9 : 'Q3',
    10 : 'Q4', 11 : 'Q4', 12 : 'Q4',
}
df['Quarter'] = df['Month'].map(quarter_dict)

# Creating a new colum that has weeks in the year
week_dict = {
    1: 'W1', 2: 'W1', 3: 'W1', 4: 'W1', 5: 'W1', 6: 'W1', 7: 'W1',
    8: 'W2', 9: 'W2', 10: 'W2', 11: 'W2', 12: 'W2', 13: 'W2', 14: 'W2',
    15: 'W3', 16: 'W3', 17: 'W3', 18: 'W3', 19: 'W3', 20: 'W3', 21: 'W3',
    22: 'W4', 23: 'W4', 24: 'W4', 25: 'W4', 26: 'W4', 27: 'W4', 28: 'W4',
    29: 'W5', 30: 'W5', 31: 'W5',
}
df['Week'] = None  # Initialize 'Week' column with None values
df['Week'] = df['Day'].map(week_dict)


# The total revenue generated from sales.
df['Total Sales'] = df['Sales'] * df['Quantity']

# The total profit generated from sales.
df['Total Profit'] = df['Profit'] * df['Quantity']

# Creating a new column by calulating profit margin
df['Profit Margin'] = ((df['Total Profit'] / df['Total Sales']) * 100).round(1)

# Creating a new colum that shows discount in percentage
df['Discount Percentage'] = df['Discount']*100

# Creating a new colum that shows number of times the Order ID is repeated
df['Order Size'] = df.groupby('Order ID')['Product Name'].transform('size')

df.info();
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8045 entries, 0 to 8046
# Data columns (total 27 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Order ID             8045 non-null   object
#  1   Order Date           8045 non-null   datetime64[ns]
#  2   Customer Name        8045 non-null   category
#  3   Country              8045 non-null   category
#  4   State                8045 non-null   category
#  5   City                 8045 non-null   category
#  6   Region               8045 non-null   category
#  7   Segment              8045 non-null   category
#  8   Ship Mode            8045 non-null   category
#  9   Category             8045 non-null   category
#  10  Sub-Category         8045 non-null   category
#  11  Product Name         8045 non-null   category
#  12  Discount             8045 non-null   float64
#  13  Sales                8045 non-null   int64
#  14  Profit               8045 non-null   int64
# ...

# %% [markdown]
# # <a id='toc5_'></a>[5 Data Analysis & Visualization ](#toc0_)

# %% [markdown]
# <h2><strong>5.1 Overview of data before analysis</strong></h2>
# <p><span style="color: #808080;">After Data Wrangling, we can check the columns once before we proceed to perform analysis</span></p>

# %%
df.columns
# Out:
# Index(['Order ID', 'Order Date', 'Customer Name', 'Country', 'State', 'City',
#        'Region', 'Segment', 'Ship Mode', 'Category', 'Sub-Category',
#        'Product Name', 'Discount', 'Sales', 'Profit', 'Quantity', 'Feedback',
#        'Year', 'Month', 'Day', 'Quarter', 'Week', 'Total Sales',
#        'Total Profit', 'Profit Margin', 'Discount Percentage', 'Order Size'],
#       dtype='object')

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><span style="color: #ffcc00;">Code Explanation:</span></p>
# <ul>
# <li ><span style="color: #808080;">df.columns; Display all columns in the data frame</span></li>
# </ul>
#
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Description of variables</span></li>
# </ul>
#
# <table style="height: 374px; width: 1000px;">
# <tbody>
# <tr style="height: 18px;">
# <td style="width: 116.75px; height: 18px; padding-left: 30px;"><strong>Variables/Columns</strong></td>
# <td style="width: 160.85px; height: 18px; padding-left: 30px;"><strong>Description</strong></td>
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Order ID</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Unique identifier for each sales transaction</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Order Date</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Date and time of the purchase</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Customer Name</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em> Name of the customer</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Country, State, City, Region</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Location of sales</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Segment</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Types of customers</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Ship Mode</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em> Shipping method chosen by the customer</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Category & Sub-Category</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Purchased product category and more specific sub category</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Product Name</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Name of the specific product purchased</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Discount and Discount Percentage</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Discount applied to the purchase (if any)</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Sales</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Total sales amount for the transaction</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Profit</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Profit earned on the transaction</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Quantity</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Quantity of each product purchased in the transaction</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Feedback</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Customer provided feedback on the purchase experience (binary)</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Year, Month, Day, Week, Quarter</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Extracted from Order Date</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Total Sales</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Sales for all items in a transaction (Product of sales and Quantity)</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Total Profit</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Profit for all items in a transaction (Product of Profit and Quantity)</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Profit Margin</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Profit margin per transaction (Total profit over total sales in percentage)</em></span></td>
#
# </tr>
# <tr style="height: 1.03334px;">
# <td style="width: 145.75px; height: 1.03334px;"><span style="color: #808080;">Order Size</span></td>
# <td style="width: 189.85px; height: 1.03334px;"><span style="color: #999999;"><em>Gives number of times the order is placed w.r.t order ID</em></span></td>
#
# </tr>
# </tbody>
# </table>
# <p>&nbsp;</p>

# %% [markdown]
# <h2><strong>5.2 Univariate analysis of all columns</strong></h2>
# <p><span style="color: #808080;"> We need to perform univariate analysis on relevent columns in Euromart data for more targetted approach </span></p>

# %% [markdown]
# <h3><span style="color: #808080;">5.2.1 Summary statistics</span></h3>
# <p data-sourcepos="3:1-3:41"><span style="color: #ffcc00;">Code Explanation:</span></p>
# <ul>
# <li><span style="color: #808080;">df.describe().T; We generate summary statistics for numerical columns in data df. and transpose the output</span></li>
# </ul>
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li><span style="color: #808080;">Summary statistics provide valuable insights of data distribution to understand our data better</span></li>
# <li><span style="color: #808080;">Notable Observations</span></li>
# <ul>
# <li><span style="color: #808080;">Discount: There are products with discounts from nil up to 85%</span></li>
# <li><span style="color: #808080;">Order Quantity: Range from single unit to 14 units </span></li>
# <li><span style="color: #808080;">Sales:Minimum sales value starts 3 USD </span></li>
# <li><span style="color: #808080;">Profit: Average profit from all transactions are in positive space at $35 USD. With average margin of 10%, which is clearly a good sign for Euro Mart </span></li>
# </ul>
# </ul>
# <p data-sourcepos="3:1-3:41"><span style="color: #808080;">Note: Numerical summary stats on categorical variable in Euro Mart data set are not yielding any valuable insights</span></p>

# %%
#Summary Statistics of Numerical Variables
df.describe().T
# Out:
#                       count                           mean  \
# Order Date             8045  2013-04-19 12:57:32.778123008
# Discount             8045.0                       0.110075
# Sales                8045.0                      291.90317
# Profit               8045.0                      35.202237
# Quantity             8045.0                       3.772281
# Total Sales          8045.0                     1479.00808
# Total Profit         8045.0                     171.520199
# Profit Margin        8045.0                      10.032293
# Discount Percentage  8045.0                      11.007458
# Order Size           8045.0                       2.904537
#
#                                      min                  25%  \
# Order Date           2011-01-01 00:00:00  2012-06-08 00:00:00
# Discount                             0.0                  0.0
# Sales                                3.0                 48.0
# Profit                           -3060.0                  1.0
# ...

# %%
#Summary Statistics of Numerical and Categrical Variables
df.describe(include='all').T
# Out:
#                       count unique                            top    freq  \
# Order ID               8045   4117                AZ-2014-7040665      11
# Order Date             8045    NaN                            NaN     NaN
# Customer Name          8045    792                    Joel Peters      32
# Country                8045     15                         France    1916
# State                  8045    127                        England    1187
# City                   8045    999                         London     219
# Region                 8045      3                        Central    4425
# Segment                8045      3                       Consumer    4173
# Ship Mode              8045      4                        Economy    4860
# Category               8045      3                Office Supplies    5284
# Sub-Category           8045     17                            Art    1151
# Product Name           8045   1810  Eldon File Cart, Single Width      26
# ...

# %% [markdown]
# <h3><span style="color: #808080;">5.2.2 Unique elements in column</span></h3>
# <p data-sourcepos="3:1-3:41"><span style="color: #ffcc00;">Code Explanation:</span></p>
# <ul>
# <li ><span style="color: #808080;">df.nunique(); Counts the number of unique elements in each column</span></li>
#
# </ul>
#
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">We got cardinality (number of distinct categories) within each column</span></li>
# <li ><span style="color: #808080;">Euro Mart operates in 15 countries. Offering 17 kinds of products category across 3 kinds of customers</span></li>
# </ul>

# %%
# Finding the cardinality of each columns
df.nunique()
# Out:
# Order ID               4117
# Order Date             1214
# Customer Name           792
# Country                  15
# State                   127
# City                    999
# Region                    3
# Segment                   3
# Ship Mode                 4
# Category                  3
# Sub-Category             17
# Product Name           1810
# Discount                 14
# Sales                  1248
# Profit                  845
# Quantity                 14
# Feedback                  2
# Year                      4
# Month                    12
# Day                      31
# Quarter                   4
# Week                      5
# Total Sales            2206
# Total Profit           1513
# Profit Margin          1133
# Discount Percentage      14
# Order Size               11
# dtype: int64

# %%
# Looking at distinct values in each columns
for col in df.columns:
    print(col)
    print(df[col].unique())
# Out:
# Order ID
# ['BN-2011-7407039' 'AZ-2011-9050313' 'AZ-2011-6674300' ...
#  'AZ-2014-7604524' 'AZ-2014-766953' 'BN-2014-4140795']
# Order Date
# <DatetimeArray>
# ['2011-01-01 00:00:00', '2011-01-03 00:00:00', '2011-01-04 00:00:00',
#  '2011-01-05 00:00:00', '2011-01-07 00:00:00', '2011-01-08 00:00:00',
#  '2011-01-11 00:00:00', '2011-01-12 00:00:00', '2011-01-13 00:00:00',
#  '2011-01-14 00:00:00',
#  ...
#  '2014-12-22 00:00:00', '2014-12-23 00:00:00', '2014-12-24 00:00:00',
#  '2014-12-25 00:00:00', '2014-12-26 00:00:00', '2014-12-27 00:00:00',
#  '2014-12-28 00:00:00', '2014-12-29 00:00:00', '2014-12-30 00:00:00',
#  '2014-12-31 00:00:00']
# Length: 1214, dtype: datetime64[ns]
# Customer Name
# ['Ruby Patel', 'Summer Hayward', 'Devin Huddleston', 'Mary Parker', 'Daniel Burke', ..., 'Bethany Powell', 'Alexandra Mahmood', 'Carol Leach', 'Charles Rice', 'Jay Collier']
# Length: 792
# ...

# %% [markdown]
# <h3><span style="color: #808080;">5.2.3 Univariate Analysis of Categorical Columns</span></h3>

# %%
# We calculate frequency(count) of unique values in the column
country_value_counts = df['Country'].value_counts() 

# We calculate percentage
country_percentages = (country_value_counts / len(df)) * 100
country_percentages

# Creating the bar chart
# Adjusting figure size for better readability
plt.figure(figsize=(8, 6))  

# Setting color scheme for bars 
colors = ['lightcoral', 'lightgrey', 'pink', 'gold', 'lightgreen', 
          'lightblue','lightcoral', 'skyblue', 'gold', 'skyblue',
          'lightgreen', 'lightblue', 'skyblue', 'lightyellow', 'lavender']

# Creating bar chart with labels and title
bars = plt.bar(country_value_counts.index, country_percentages, color=colors)
plt.xlabel("Country")
plt.ylabel("Percentage (%)")
plt.title("Distribution of Countries (with Percentages)")

# Adding percentages as text labels on top of bars
for bar, perc in zip(bars, country_percentages):
  plt.text(bar.get_x() + bar.get_width() / 2, perc + 0.2, f"{perc:.1f}%", ha='center', va='bottom');

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding gridlines on the x & y axis
plt.grid(axis='y', linestyle='--', alpha=0.7)  
plt.grid(axis='x', linestyle='--', alpha=0.7) 

# Adjusting space between chart
plt.tight_layout()

# Displaying the graph
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">France has the highest percentage at 23.8%, followed by Germany (20.4%), and the United Kingdom (16.3%)  </span></li>
# <li ><span style="color: #808080;">The other countries have progressively smaller percentages, with Denmark having the lowest at 0.7%  </span></li>
# <li ><span style="color: #808080;">France, Germany, and the United Kingdom are the most significant contributors to the Sales of EuroMart  </span></li>
#
# </ul>

# %%
# We calculate frequency(count) of unique values in the column
state_value_counts = df['State'].value_counts().sort_values(ascending=False).head(10)

# We calculate percentage
state_percentages = (state_value_counts / len(df)) * 100

# Creating the bar chart
# Adjusting figure size for better readability
plt.figure(figsize=(10, 6.5))

# Setting color scheme for bars 
colors = ['skyblue', 'lightcoral', 'lightgreen', 'lightgrey', 'lightblue', 'pink', 'lightgreen', 'gold', 'lightcoral', 'skyblue']


# Creating bar chart with labels and title
bars = plt.bar(state_value_counts.index, state_percentages, color=colors)
plt.xlabel("Top 10 States", fontsize=14)
plt.ylabel("Percentage (%)", fontsize=14)
plt.title("Distribution of Top 10 States (with Percentages)", fontsize=16)

# Adding percentages as text labels on top of bars with slight adjustment for positioning
for bar, perc in zip(bars, state_percentages):
    plt.text(bar.get_x() + bar.get_width() / 2, perc + 0.01, f"{perc:.1f}%", ha='center', va='bottom', fontsize=10)

# Rotate x-axis labels for better readability
plt.xticks(rotation=20, ha='right', fontsize=12)

# Adding gridlines on the x & y axis
plt.grid(axis='y', linestyle='--', alpha=0.7)  
plt.grid(axis='x', linestyle='--', alpha=0.7) 

# Adjusting space between chart
plt.tight_layout()

# Displaying the graph
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">England has the highest percentage at approximately 14.8%, followed by Île-de-France at around 8.4% and North Rhine-Westphalia by 7.1%</span></li>
# <li ><span style="color: #808080;">The other regions have percentages decreasing from roughly 3.1% to about 1.9%</span></li>
# <li ><span style="color: #808080;">England and Île-de-France are the most significant state contributors</span></li>
#
# </ul>

# %%
# Getting the number of categories in variable
segment_counts = df['Segment'].value_counts()

# Pie chart
# Adjusting figure size for better readability
plt.figure(figsize=(3, 3))

# Defining list to "explode" pie chart slices
explode = [0.1, 0, 0]

#Setting colours to the piechart slices
colors = ['lightgrey', 'lightblue', 'pink']

# Creating the pie chart
plt.pie(segment_counts, labels=segment_counts.index, explode=explode, autopct="%1.1f%%", colors=colors)

# Adding title to the chart
plt.title("Distribution of different customer segment") 

# Displaying the chart
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Consumer is the largest segment, likely accounting for around 51.9% of the total customers</span></li>
# <li ><span style="color: #808080;">Corporate is the second largest segment contributing to 31.2%</span></li>
# <li ><span style="color: #808080;">Home Office is the smallest segment, 16.9% of the customers</span></li>
#
# </ul>

# %%
# Getting the number of categories in variable
shipping_modes_counts = df['Ship Mode'].value_counts()

# Pie chart
# Adjusting figure size for better readability
plt.figure(figsize=(3, 3))

# Defining list to "explode" pie chart slices
explode = [0.1, 0, 0, 0]

#Setting colours to the piechart slices
colors = ['lightgreen', 'gold', '#C1F0F8', 'lavender']

# Creating the pie chart
plt.pie(shipping_modes_counts, labels=shipping_modes_counts.index, explode=explode, autopct="%1.1f%%", colors = colors)

# Adding title to the chart
plt.title("Distribution of different shipping modes")

# Displaying the chart
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Economy is the most used shipping mode, accounting for the largest portion, followed by Economy plus and Priority</span></li>
# <li ><span style="color: #808080;">Immediate is the least used mode among the options presented</span></li>
#
#
# </ul>

# %%
# Getting the number of categories in variable
category_counts = df['Category'].value_counts()

# Pie chart
# Adjusting figure size for better readability
plt.figure(figsize=(3, 3))

# Defining list to "explode" pie chart slices
explode = [0.1, 0, 0]

#Setting colours to the piechart slices
colors = ['skyblue', 'lightpink', 'lightgreen']

# Creating the pie chart
plt.pie(category_counts, labels=category_counts.index, explode=explode, autopct="%1.1f%%", colors = colors)

# Adding title to the chart
plt.title("Distribution of different category of goods")

# Displaying the chart
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Office Supplies: This category constitutes the largest portion, accounting for 65.7% of the goods</span></li>
# <li ><span style="color: #808080;">Furniture: Furniture makes up to 18.9% of the total</span></li>
# <li ><span style="color: #808080;">Technology: The smallest segment is technology, representing  15.4%</span></li>
#
# </ul>

# %%
# Getting the counts of categories
# Sorting them by count in descending order
# Selecting the top 5
subcategory_value_counts = df['Sub-Category'].value_counts().sort_values(ascending=False).head()

# caluclating percentages
subcategory_value_percentages = (subcategory_value_counts / len(df)) * 100

# Creating the bar chart
# Adjusting figure size for better readability
plt.figure(figsize=(8, 4))

# Setting color scheme for bars 
colors = ['skyblue', 'lightgrey', 'pink', 'gold', 'lightcoral'] 

# Creating bar chart with labels and title
bars = plt.bar(subcategory_value_counts.index, subcategory_value_percentages, color=colors)
plt.xlabel("Sub-Category")
plt.ylabel("Percentage (%)")
plt.title("Distribution of Top 5 Sub-Category of goods (with Percentages)")
  
# Adding percentages as text labels on top of bars with slight adjustment for positioning
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height + 0.01, f"{height:.1f}%", ha='center', va='bottom')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adjusting space between chart
plt.tight_layout()

# Displaying the graph
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Art: This sub-category represents 14.3% of the goods</span></li>
# <li ><span style="color: #808080;">Binders: Binders account for 13.2%</span></li>
# <li ><span style="color: #808080;">Storage: The storage sub-category makes up 13.1%</span></li>
# <li ><span style="color: #808080;">Phones: Phones have a smaller share of 5.6%</span></li>
# <li ><span style="color: #808080;">Bookcases: Bookcases are the smallest segment, comprising for 4.9%</span></li>
# </ul>

# %%
# Getting the number of categories in variable
feedback_counts = df['Feedback'].value_counts()

# Pie chart
# Adjusting figure size for better readability
plt.figure(figsize=(3, 3))

# Creating the pie chart
plt.pie(feedback_counts, labels=feedback_counts.index, autopct="%1.1f%%")

# Adding title to the chart
plt.title("Distribution of feedback provided on purchase")

# Displaying the chart
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Almost half of the customers have given feedback on product purchase</span></li>
#
# </ul>

# %% [markdown]
# <h3><span style="color: #808080;">5.2.3 Univariate Analysis of Numerical Columns</span></h3>

# %%
# Creating a figure with 2 subplots (one on top of the other)
fig, (ax1, ax2) = plt.subplots(2, figsize=(15, 10))

# Plotting the histogram on the top subplot (ax1)
ax1.hist(df['Discount Percentage'], color='skyblue', edgecolor='#03AED2')

# display count on bars
for i in ax1.patches:  # Iterate over each bar in the chart
    height = i.get_height()  # Get the height of the bar
    ax1.text(i.get_x() + i.get_width() / 2, height + 40, str(int(height)), ha='center', fontsize=10)

# Adding title to the chart
ax1.set(title='Distribution of discount in %', ylabel='count')

# Plotting the boxplot on the bottom subplot (ax2)
ax2.boxplot(df['Discount Percentage'], labels=['All'], vert=False, showmeans=True, showfliers=True)  # Show means as diamonds & plot box plot

# Adding title to the boxplot
ax2.set(xlabel='Discount Percentage')

#Display the summary statistics
display(df["Discount Percentage"].describe().round(2))
# Out:
# count    8045.00
# mean       11.01
# std        18.18
# min         0.00
# 25%         0.00
# 50%         0.00
# 75%        10.00
# max        85.00
# Name: Discount Percentage, dtype: float64

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">There’s a significant spike in 0 to 20% discount range, indicating higher products presence in this discount range</span></li>
# <li ><span style="color: #808080;">The box plot represents the interquartile range (IQR) with whiskers extending to show the range of discount percentages. Several outliers are visible beyond the whiskers</span></li>
# <li ><span style="color: #808080;">Positively skewed distribution; here mean > median</span></li>
# </ul>

# %%
# Creating a figure with 2 subplots (one on top of the other)
fig, (ax1, ax2) = plt.subplots(2, figsize=(15, 10))

# Plotting the histogram on the top subplot (ax1)
ax1.hist(df['Total Profit'], bins=20, color='#DC8686', edgecolor='#776B5D')

# display count on bars
for i in ax1.patches:  # Iterate over each bar in the chart
    height = i.get_height()  # Get the height of the bar
    ax1.text(i.get_x() + i.get_width() / 2, height + 70, str(int(height)), ha='center', fontsize=12)

# Adding title to the chart
ax1.set(title='Distribution of Total Profit', ylabel='Count')

# Plotting the boxplot on the bottom subplot (ax2)
ax2.boxplot(df['Total Profit'], labels=['All'], vert=False, showmeans=True, showfliers=True)

# Adding title to the boxplot
ax2.set(xlabel='Total Profit')

#Display the summary statistics
display(df["Total Profit"].describe().round(2))

# Adjusting layout for better spacing
plt.tight_layout()  

# Displaying the chart
plt.show()
# Out:
# count     8045.00
# mean       171.52
# std       1325.59
# min     -36720.00
# 25%          1.00
# 50%         40.00
# 75%        182.00
# max      29712.00
# Name: Total Profit, dtype: float64

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Profit lies in postitive and negetaive axis</span></li>
# <li ><span style="color: #808080;">The box plot represents several outliers are visible beyond the whiskers</span></li>
# <li ><span style="color: #808080;">The variable looks almost normally distributed; mean and median are almost near to each other w.r.t spread of profit values in x-axis</span></li>
# </ul>

# %%
# Creating a figure with 2 subplots (one on top of the other)
fig, (ax1, ax2) = plt.subplots(2, figsize=(15, 8))

# Plotting the histogram on the top subplot (ax1)
ax1.hist(df['Profit Margin'], color='#AD88C6', edgecolor='#7469B6')

# display count on bars
for i in ax1.patches:  # Iterate over each bar in the chart
    height = i.get_height()  # Get the height of the bar
    ax1.text(i.get_x() + i.get_width() / 2, height + 40, str(int(height)), ha='center', fontsize=10)

# Adding title to the chart
ax1.set(title='Distribution of profit margin in %', ylabel='count') #Assign labels and title

# Plotting the boxplot on the bottom subplot (ax2)
ax2.boxplot(df['Profit Margin'], labels=['All'], vert=False, showmeans=True, showfliers=True)  # Show means as diamonds & plot box plot

# Adding title to the boxplot
ax2.set(xlabel='Distribution of profit margin in %')

#Display the summary statistics
display(df["Profit Margin"].describe().round(2))
# Out:
# count    8045.00
# mean       10.03
# std        34.01
# min      -387.10
# 25%         1.10
# 50%        17.10
# 75%        33.00
# max        52.40
# Name: Profit Margin, dtype: float64

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Profit margin; Most bars cluster around the -100% to 0% range, suggesting a significant number of observations within this interval</span></li>
# <li ><span style="color: #808080;">Fewer counts extend toward -300%, indicating less common occurrences</span></li>
# <li ><span style="color: #808080;">Negatively skewed distribution; here, the mean < median</span></li>
# </ul>

# %%
# Creating a figure with 2 subplots (one on top of the other)
fig, (ax1, ax2) = plt.subplots(2, figsize=(15, 10))

# Plotting the histogram on the top subplot (ax1)
ax1.hist(df['Quantity'], color='#A0D995', edgecolor='#F6FBF4')

# Adding title to the chart
ax1.set(title='Distribution of quantity in units', ylabel='count')

# Plotting the boxplot on the bottom subplot (ax2)
ax2.boxplot(df['Quantity'], labels=['All'], vert=False, showmeans=True, showfliers=True)  # Show means as diamonds & plot box plot

# display count on bars
for i in ax1.patches:  # Iterate over each bar in the chart
    height = i.get_height()  # Get the height of the bar
    ax1.text(i.get_x() + i.get_width() / 2, height + 40, str(int(height)), ha='center', fontsize=12)

# Adding title to the boxplot
ax2.set(xlabel='Distribution of quantity in units'); #Assign labels and title

#Display the summary statistics
display(df["Quantity"].describe().round(2)) #Print summary statistics
# Out:
# count    8045.00
# mean        3.77
# std         2.20
# min         1.00
# 25%         2.00
# 50%         3.00
# 75%         5.00
# max        14.00
# Name: Quantity, dtype: float64

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Sales quantity; most bars cluster around the 0 to 2 units range, indicating a higher occurrence of values within this interval</span></li>
# <li ><span style="color: #808080;">Median is 3, Customers ordered most of the times 3 quantities in order </span></li>
# <li ><span style="color: #808080;">Positively skewed distribution; here, the mean > median</span></li>
# </ul>

# %%
# Creating a figure and adjusting figure size for better readability
fig, (ax1) = plt.subplots(1, figsize=(14, 5))

# Plotting the histogram
ax1.hist(df['Month'], bins=12, color='#B784B7', edgecolor='#F5E8DD')

# Setting labels
month_names = ['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
plt.xticks(range(1, 13), month_names)  # Set month names for x-axis ticks

# Adding title to the chart
ax1.set(title='Distribution of sales in Months', ylabel='Count of sales', xlabel='Month')

# display count on bars
for i in ax1.patches:  # Iterate over each bar in the chart
    height = i.get_height()  # Get the height of the bar
    ax1.text(i.get_x() + i.get_width() / 2, height + 1, str(int(height)), ha='center', fontsize=12)

# Adjusting space between chart
plt.tight_layout()

# Displaying the graph
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Most of the sales happened in August, followed by September, November, December and June month</span></li>
# <li ><span style="color: #808080;">First half of the year has low sales compared to next half of the year</span></li>
#
# </ul>

# %%
# Creating a figure and adjusting figure size for better readability
fig, (ax1) = plt.subplots(1, figsize=(15, 3))

# Plotting the histogram
ax1.hist(df['Day'], color='#C4DFDF', edgecolor='#E3F4F4')

# display count on bars
for i in ax1.patches:  # Iterate over each bar in the chart
    height = i.get_height()  # Get the height of the bar
    ax1.text(i.get_x() + i.get_width() / 2, height + 5, str(int(height)), ha='center', fontsize=10)

# Adding title to the chart and fixing y axis range
ax1.set(title='Distribution of sales in calender days', ylabel='Count of sales', xlabel='Day')
ax1.set_ylim(bottom=600)

# Adjusting space between chart
plt.tight_layout()

# Displaying the graph
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Most of the sales observed in month end from 25th to 31st calender dates (Last 6 days) and followed by range of 10 to 20th calender dates (Middle of month)</span></li>
#
# </ul>

# %% [markdown]
# <h2><strong>5.4 Multi Variate Analysis</strong></h2>

# %% [markdown]
# <h3><span style="color: #808080;">5.4.1 Identifying Top Performers</span></h3>

# %%
# Creating a figure and adjusting figure size for better readability
fig, (ax1) = plt.subplots(1, figsize=(10, 5))

# Calculating correlations of numerical datatypes
correlation = df.select_dtypes(include=[np.number]).corr()

# Creating a heatmap to visualize correlations
sns.heatmap(correlation, annot=True, cmap="PiYG")  # Heatmap of correlations between numerical features

# Adding title to the chart
plt.title("Correlation Heatmap")

# Displaying the graph
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Identifying potential relationships among target variables (Sales, Profit)</span></li>
# <li ><span style="color: #808080;">We see that there is positive correlation among Sales, Profit and Quantity</span></li>
# <li ><span style="color: #808080;">We are ignoring relation among Target variables (Sales, Profit) with Total sales, Profit margin, Discount percentage and Order size because those variables were derived from target variables</span></li>
# </ul>

# %%
# Split by region

# Setting figure size for readability
plt.figure(figsize=(16, 10))

# Subplot 1: region vs Sales (Bar Graph)
# Positioning subplot at row 2, column 2, position 1
plt.subplot(2, 2, 1)

# Aggregate based on categories
region_sales = df.groupby('Region')['Sales'].sum()

# Converting to percentage
region_sales = region_sales / region_sales.sum() * 100

# Creating bar chart with annotations
plt.bar(region_sales.index, region_sales, color='#ECC5FB', alpha=0.5, label='Sales (%)')

# Plotting horizontal line represting average value
plt.axhline(y=(region_sales.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Region')
plt.ylabel('Sales (%)')

# Adding title to the chart
plt.title('Total Sales by Region (%)')

# Adding percentages as text labels on top of bars with slight adjustment for positioning
for i, v in enumerate(region_sales):
    plt.text(i, v - 0.3, f"{v:.1f}%", ha='center', va='bottom', fontsize=10)  # Adjust 'v + 1' for better positioning
plt.xticks(rotation=45, ha='right')


# Subplot 2: region vs Profit Margin (Bar Graph)
# Positioning subplot at row 2, column 2, position 3
plt.subplot(2, 2, 3)

# Aggregate based on categories
region_profit = df.groupby('Region')['Profit Margin'].mean()

# Creating bar chart with annotations
plt.bar(region_profit.index, region_profit, color='lightblue', label='Profit')

# Creating scatter plot to overalp on bar chart
plt.scatter(region_profit.index, region_profit.values, color='red', alpha=0.5)

# Plotting horizontal line represting average value
plt.axhline(y=(region_profit.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Region')
plt.ylabel('Average Profit Margin (in%)')

# Adding title to the chart
plt.title('Average Profit Margin by Region (in%)')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding percentages as text labels on top of bars with slight adjustment for positioning
for i, v in enumerate(region_profit):
    plt.text(i, v - 0, f"{v:.1f}%", ha='center', va='bottom', fontsize=10)  # Adjust 'v + 1' for better positioning
plt.xticks(rotation=45, ha='right')


# Subplot 3: region vs Quantity (Bar Graph)
# Positioning subplot at row 2, column 2, position 2
plt.subplot(2, 2, 2)

# Aggregate based on categories
region_quantity = df.groupby('Region')['Quantity'].mean()

# Creating bar chart with annotations
plt.bar(region_quantity.index, region_quantity, color='#87CEEB')

# Creating scatter plot to overalp on bar chart
plt.scatter(region_quantity.index, region_quantity.values, color='red', alpha=0.5)

# Plotting horizontal line represting average value
plt.axhline(y=(region_quantity.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Region')
plt.ylabel('Average Quantity')

# Adding title to the chart
plt.title('Average Quantity by Region')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding percentages as text labels on top of bars with slight adjustment for positioning
for i, v in enumerate(region_quantity):
    plt.text(i, v - 0, f"{v:.1f}%", ha='center', va='bottom', fontsize=10)  # Adjust 'v + 1' for better positioning
plt.xticks(rotation=45, ha='right')

# Adding legend to the chart
plt.legend()

# Adjusting space between chart
plt.tight_layout()

# Displaying the graph
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Total Sales by Region: The Central region has the highest percentage of sales at 56.0%. North & South region both account for 22.2% of sales</span></li>
# <li ><span style="color: #808080;">Average Quantity by Region: All regions show similar average quantities, hovering around 3.5 units</span></li>
# <li ><span style="color: #808080;">Average Profit Margin by Region (%): Central and Soutth regions are contributing above the average profit margin compared to north region</span></li>
# </ul>

# %%
# Split by country

# Setting figure size for readability
plt.figure(figsize=(16, 10))

# Subplot 1: Country vs Sales (Bar Graph)
# Positioning subplot at row 2, column 2, position 1
plt.subplot(2, 2, 1)

# Aggregate based on categories
country_sales = df.groupby('Country')['Sales'].sum()

# Converting to percentage
country_sales = country_sales / country_sales.sum() * 100


# Creating bar chart with annotations
plt.bar(country_sales.index, country_sales, color='#C08B5C', alpha=0.5, label='Sales (%)')

# Plotting horizontal line represting average value
plt.axhline(y=(country_sales.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Country')
plt.ylabel('Sales (%)')

# Adding percentages as text labels on top of bars with slight adjustment for positioning
plt.title('Total Sales by Country (%)')
for i, v in enumerate(country_sales):
    plt.text(i, v + 0.01, f"{v:.1f}%", ha='center', va='bottom', fontsize=10)  # Adjust 'v + 1' for better positioning
plt.xticks(rotation=45, ha='right')


# Subplot 2: Country vs Profit (Line)
# Positioning subplot at row 2, column 2, position 3
plt.subplot(2, 2, 3)

# Aggregate based on categories
country_profit = df.groupby('Country')['Profit Margin'].mean()

# Creating line chart with annotations
plt.plot(country_profit.index, country_profit, color='#939B62', label='Profit')

# Creating scatter plot to overalp on line chart
plt.scatter(country_profit.index, country_profit.values, color='red', alpha=0.5)

# Plotting horizontal line at y=0 (zero profit)
plt.axhline(y=0, color='gray', linestyle='dashed', linewidth=0.8, label='Zero Profit')

# Adding labels to the chart
plt.xlabel('Country')
plt.ylabel('Average Profit Margin (in%)')

# Adding title to the chart
plt.title('Average Profit Margin by Country (in%)')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')


# Subplot 3: Country vs Quantity (Line)
# Positioning subplot at row 2, column 2, position 2
plt.subplot(2, 2, 2)

# Aggregate based on categories
country_quantity = df.groupby('Country')['Quantity'].mean()

# Creating line chart with annotations
plt.plot(country_quantity.index, country_quantity, color='#E178C5', label='Quantity (mean)')

# Creating scatter plot to overalp on chart
plt.scatter(country_quantity.index, country_quantity.values, color='red', alpha=0.5)

# Plotting horizontal line represting average value
plt.axhline(y=(country_quantity.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Country')
plt.ylabel('Average Quantity')

# Adding title to the chart
plt.title('Average Quantity by Country')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding legend to the chart
plt.legend()

# Adjusting space between chart
plt.tight_layout()

# Displaying the graph
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Total Sales by Country: France, Germany, UK, Italy and Spain are having good sales contribution above the average sales among all the countries</span></li>
# <li ><span style="color: #808080;">Average Quantity by Country: Order quantity ranges from 3 to 4 units among all country</span></li>
# <li ><span style="color: #808080;">Average Profit Margin by Country (%): On average Euro Mart is incurring loss with negative profit margin in countries like Denmark, Ireland, Netherlands, Portugal and Sweden </span></li>
# </ul>

# %%
# Split by states

# Set figure size
# Adjusting figure size for better readability
plt.figure(figsize=(16, 14))

# Subplot 1: Top 10 State vs Sales (Bar Graph)
# Positioning subplot at row 3, column 2, position 1
plt.subplot(3, 2, 1)

# Aggregate based on categories and sort by decending order, select top 10
State_sales = df.groupby('State')['Sales'].sum().sort_values(ascending=False).head(10)

# Converting to percentage
State_sales = State_sales / State_sales.sum() * 100

# Creating bar chart with annotations
plt.bar(State_sales.index, State_sales, color='#B7CADB', alpha=0.5, label='Sales (%)')

# Plotting horizontal line represting average value
plt.axhline(y=(State_sales.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('State')
plt.ylabel('Sales (%)')

# Adding title to the chart
plt.title('Total Sales by top 10 States (%)')

# Adding percentages as text labels on top of bars with slight adjustment for positioning
# Selecting top 10 values
top_states = State_sales.nlargest(10)
for i, v in enumerate(top_states):
    plt.text(i, v + 0.01, f"{v:.1f}%", ha='center', va='bottom', fontsize=10)
plt.xticks(rotation=20, ha='right')


# Subplot 2: Bottom 10 State vs Sales (Bar Graph)
# Positioning subplot at row 3, column 2, position 2
plt.subplot(3, 2, 2)

# Aggregate based on categories and sort by decending order, select bottom 10
State_sales_bottom = df.groupby('State')['Sales'].sum().sort_values(ascending=False).tail(10)

# Converting to percentage
State_sales_bottom = State_sales_bottom / State_sales_bottom.sum() * 100

# Creating bar chart with annotations
plt.bar(State_sales_bottom.index, State_sales_bottom, color='#8644A2', alpha=0.5, label='Sales (%)')

# Plotting horizontal line represting average value
plt.axhline(y=(State_sales_bottom.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('State')
plt.ylabel('Sales (%)')

# Adding title to the chart
plt.title('Total Sales by bottom 10 States (%)')

# Adding percentages as text labels on top of bars with slight adjustment for positioning
# Selecting bottom 10 values
bottom_10_states_sales = State_sales_bottom.nsmallest(10).sort_values(ascending=False)
for i, v in enumerate(bottom_10_states_sales):
    plt.text(i, v + 0.01, f"{v:.1f}%", ha='center', va='bottom', fontsize=10)
plt.xticks(rotation=20, ha='right')


# Subplot 3: top 10 State vs Profit (Line)
# Positioning subplot at row 3, column 2, position 3
plt.subplot(3, 2, 3)

# Aggregate based on categories and sort by decending order, select bottom 10
state_profit = df.groupby('State')['Profit Margin'].mean().sort_values(ascending=False).head(10)


# Converting to percentage
state_profit = state_profit / state_profit.sum() * 100

# Creating line chart with annotations
plt.plot(state_profit.index, state_profit, color='green', label='Profit')

# Creating scatter plot to overalp on chart
plt.scatter(state_profit.index, state_profit.values, color='red', alpha=0.5)

# Plotting horizontal line represting average value
plt.axhline(y=(state_profit.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('State')
plt.ylabel('Average Profit Margin (in%)')

# Adding title to the chart
plt.title('Average Profit Margin by top 10 States (in%)')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')


# Subplot 4: bottom 10 State vs Profit (Line)
plt.subplot(3, 2, 4)
# Positioning subplot at row 3, column 2, position 4

# Aggregate based on categories and sort by decending order, select bottom 10
state_profit_bottom_profit = df.groupby('State')['Profit Margin'].mean().sort_values(ascending=False).tail(10)


# Converting to  percentage
state_profit_bottom_profit = state_profit_bottom_profit / state_profit_bottom_profit.sum() * 100

# Creating line chart with annotations
plt.plot(state_profit_bottom_profit.index, state_profit_bottom_profit, color='#D5DBB3', label='Profit')

# Creating scatter plot to overalp on chart
plt.scatter(state_profit_bottom_profit.index, state_profit_bottom_profit.values, color='red', alpha=0.5)

# Plotting horizontal line represting average value
plt.axhline(y=(state_profit_bottom_profit.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('State')
plt.ylabel('Average Profit Margin (in%)')

# Adding title to the chart
plt.title('Average Profit Margin by bottom 10 States')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')


# Subplot 5: State vs Quantity (Line)
# Positioning subplot at row 3, column 2, position 3
plt.subplot(3, 2, 5)

# Aggregate based on categories and sort by decending order, select top 10
state_quantity = df.groupby('State')['Quantity'].mean().sort_values(ascending=False).head(10)

# Creating bar chart with annotations
plt.plot(state_quantity.index, state_quantity, color='purple', label='Quantity (mean)')

# Creating scatter plot to overalp on chart
plt.scatter(state_quantity.index, state_quantity.values, color='red', alpha=0.5)

# Plotting horizontal line represting average value
plt.axhline(y=(state_quantity.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('State')
plt.ylabel('Average Quantity')

# Adding title to the chart
plt.title('Average Quantity by State')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding legend to the chart
plt.legend()


# Subplot 6: State vs Quantity (Line)
# Positioning subplot at row 3, column 2, position 6
plt.subplot(3, 2, 6)

# Aggregate based on categories and sort by decending order, select bottom 10
state_quantity = df.groupby('State')['Quantity'].mean().sort_values(ascending=False).tail(10)

# Creating line chart with annotations
plt.plot(state_quantity.index, state_quantity, color='#AEE6E6', label='Quantity (mean)')

# Creating scatter plot to overalp on chart
plt.scatter(state_quantity.index, state_quantity.values, color='red', alpha=0.5)

# Plotting horizontal line represting average value
plt.axhline(y=(state_quantity.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('State')
plt.ylabel('Average Quantity')

# Adding title to the chart
plt.title('Average Quantity by State')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding legend to the chart
plt.legend()

# Adjusting space between chart
plt.tight_layout()

# Displaying the graph
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #808080;">Analysis by top 10 states</span></strong></p>
# <li ><span style="color: #808080;">Total Sales by State:England, France, North Rihne-Westphalia are contributing to ~66% of top 10 states</span></li>
# <li ><span style="color: #808080;">Average Profit Margin by State(%):Top 10 states are contributing to positive profit margin above 9.25%. This is good sign for Euromart</span></li>
# <li ><span style="color: #808080;">Average Quantity by State:Average order quantity are in higher side ranging from 4.5 to 9 units</span></li>
# </ul>
#
# <ul>
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #808080;">Analysis by bottom 10 states</span></strong></p>
# <li ><span style="color: #808080;">Total Sales by State:Zealand, Galway, Kymenlaakso, Extermadura, Zeeland & Setubal are contributing to ~80% of bottom 10 states</span></li>
# <li ><span style="color: #808080;">Average Profit Margin by State(%):Bottom 10 states are contributing to positive profit margin above 7%. This is good sign for Euromart</span></li>
# <li ><span style="color: #808080;">Average Quantity by State:Average order quantity are in lower side ranging from 1.5 to 3 units</span></li>
# </ul>

# %%
# Split by City

# Set figure size
plt.figure(figsize=(16, 16))

# Subplot 1: Top 10 City vs Sales (Bar Graph)
# Positioning subplot at row 3, column 2, position 1
plt.subplot(3, 2, 1)

# Aggregate based on categories and sort by decending order, select top 10
City_sales = df.groupby('City')['Sales'].sum().sort_values(ascending=False).head(10)

# Converting to percentage
City_sales = City_sales / City_sales.sum() * 100

# Creating bar chart with annotations
plt.bar(City_sales.index, City_sales, color='#9EB23B', alpha=0.5, label='Sales (%)')

# Plotting horizontal line represting average value
plt.axhline(y=(City_sales.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('City')
plt.ylabel('Sales (%)')

# Adding title to the chart
plt.title('Total Sales by top 10 Cities (%)')

# Adding percentages as text labels on top of bars with slight adjustment for positioning
# Selecting bottom 10 values
top_City = City_sales.nlargest(10)
for i, v in enumerate(top_City):
    plt.text(i, v + 0.01, f"{v:.1f}%", ha='center', va='bottom', fontsize=10)

# Rotating x-axis labels for better readability
plt.xticks(rotation=20, ha='right')


# Subplot 2: Bottom 10 City vs Sales (Bar Graph)
# Positioning subplot at row 3, column 2, position 2
plt.subplot(3, 2, 2)

# Aggregate based on categories and sort by decending order, select bottom 10
City_sales_bottom = df.groupby('City')['Sales'].sum().sort_values(ascending=False).tail(10)

# Converting to percentage
City_sales_bottom = City_sales_bottom / City_sales_bottom.sum() * 100

# Creating bar chart with annotations
plt.bar(City_sales_bottom.index, City_sales_bottom, color='#B34180', alpha=0.5, label='Sales (%)')

# Plotting horizontal line represting average value
plt.axhline(y=(City_sales_bottom.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('City')
plt.ylabel('Sales (%)')

# Adding title to the chart
plt.title('Total Sales by bottom 10 Cities (%)')

# Adding percentages as text labels on top of bars with slight adjustment for positioning
# Selecting bottom 10 values
bottom_10_City_sales = State_sales_bottom.nsmallest(10).sort_values(ascending=False)
for i, v in enumerate(bottom_10_City_sales):
    plt.text(i, v-0.4, f"{v:.1f}%", ha='center', va='top', fontsize=10)  # Adjust 'v + 1' for better positioning
plt.xticks(rotation=45, ha='right')

# Rotating x-axis labels for better readability
plt.xticks(rotation=20, ha='right')


# Subplot 3: top 10 City vs Profit Margin (Line)
# Positioning subplot at row 3, column 2, position 3
plt.subplot(3, 2, 3)

# Aggregate based on categories and sort by decending order, select top 10
City_profit = df.groupby('City')['Profit Margin'].mean().sort_values(ascending=False).head(10)

# Converting to percentage
City_profit = City_profit / City_profit.sum() * 100

# Creating line chart with annotations
plt.plot(City_profit.index, City_profit, color='green', label='Profit')

# Creating scatter plot to overalp on chart
plt.scatter(City_profit.index, City_profit.values, color='red', alpha=0.5, label="Sales (sum)")

# Plotting horizontal line represting average value
plt.axhline(y=(City_profit.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('City')
plt.ylabel('Average Profit Margin (in%)')

# Adding title to the chart
plt.title('Average Profit Margin by top 10 Cities (in%)')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')


# Subplot 4: bottom 10 City vs Profit (Line)
# Positioning subplot at row 3, column 2, position 4
plt.subplot(3, 2, 4)

# Aggregate based on categories and sort by decending order, select bottom 10
City_profit_bottom_profit = df.groupby('City')['Profit Margin'].mean().sort_values(ascending=False).tail(10)

# Converting to percentage
City_profit_bottom_profit = City_profit_bottom_profit / City_profit_bottom_profit.sum() * 100

# Creating line chart with annotations
plt.plot(City_profit_bottom_profit.index, City_profit_bottom_profit, color='#7C064D', label='Profit')

# Creating scatter plot to overalp on chart
plt.scatter(City_profit_bottom_profit.index, City_profit_bottom_profit.values, color='red', alpha=0.5, label="Sales (sum)")

# Plotting horizontal line represting average value
plt.axhline(y=(City_profit_bottom_profit.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('City')
plt.ylabel('Average Profit Margin (in%)')

# Adding title to the chart
plt.title('Average Profit Margin by bottom 10 Cities (in%)')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')


# Subplot 5: City vs Quantity (Line)
# Positioning subplot at row 3, column 2, position 5
plt.subplot(3, 2, 5)

# Aggregate based on categories and sort by decending order, select top 10
state_quantity = df.groupby('City')['Quantity'].mean().sort_values(ascending=False).head(10)

# Creating line chart with annotations
plt.plot(state_quantity.index, state_quantity, color='#4C8492', label='Quantity (mean)')

# Creating scatter plot to overalp on chart
plt.scatter(state_quantity.index, state_quantity.values, color='red', alpha=0.5, label="Sales (sum)")

# Plotting horizontal line represting average value
plt.axhline(y=(state_quantity.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('City')
plt.ylabel('Average Quantity')

# Adding title to the chart
plt.title('Average Quantity by top 10 Cities')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding legend to the chart
plt.legend()


# Subplot 6: City vs Quantity (Line)

plt.subplot(3, 2, 6)
# Positioning subplot at row 3, column 2, position 6

# Aggregate based on categories and sort by decending order, select bottom 10
country_quantity = df.groupby('City')['Quantity'].mean().sort_values(ascending=False).tail(10)

# Creating line chart with annotations
plt.plot(country_quantity.index, country_quantity, color='#D0EF84', label='Quantity (mean)')

# Creating scatter plot to overalp on chart
plt.scatter(country_quantity.index, country_quantity.values, color='red', alpha=0.5, label="Sales (sum)")

# Plotting horizontal line represting average value
plt.axhline(y=(country_quantity.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('City')
plt.ylabel('Average Quantity')

# Adding title to the chart
plt.title('Average Quantity by bottom 10 Cities')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding legend to the chart
plt.legend()

# Adjusting space between chart
plt.tight_layout()

# Displaying the graph
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #808080;">Analysis by top 10 Cities</span></strong></p>
# <li ><span style="color: #808080;">Total Sales by Cities:London, Berlin, Vienna, Madrid, Paris are contributing to ~68% of top 10 Cities</span></li>
# <li ><span style="color: #808080;">Average Profit Margin by Cities(%):Top 10 Cities are contributing to positive profit margin range of 9.8% to 10.3%. This is good sign for Euromart</span></li>
# <li ><span style="color: #808080;">Average Quantity by Cities:Average order quantity are in higher side ranging from 8 to 12 units</span></li>
# </ul>
#
# <ul>
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #808080;">Analysis by bottom 10 Cities</span></strong></p>
# <li ><span style="color: #808080;">Total Sales by Cities:Cestas, Ragusa, Battipaglia, Millau, Leiden, Friedenberg are contributing to ~80% of bottom 10 Cities</span></li>
# <li ><span style="color: #808080;">Average Profit Margin by Cities(%):Bottom 10 Cities are contributing to positive profit margin above 8.5%. This is good sign for Euromart</span></li>
# <li ><span style="color: #808080;">Average Quantity by Cities:Average order quantity are in lower side of only 1 unit. This is a concern for Euromart</span></li>
# </ul>

# %%
# Split by Segment

# Setting figure size for better readability
plt.figure(figsize=(16, 10))

# Subplot 1:Segment vs Sales (Bar Graph)
# Positioning subplot at row 2, column 2, position 1
plt.subplot(2, 2, 1)

# Aggregate based on categories, sort by descending order and select top 10 values
segment_sales = df.groupby('Segment')['Sales'].sum().sort_values(ascending=False)

# Converting to percentage
segment_sales = segment_sales / segment_sales.sum() * 100

# Creating bar chart with annotations
plt.bar(segment_sales.index, segment_sales,  color='#80BCBD')

# Plotting horizontal line represting average value
plt.axhline(y=(segment_sales.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Segment')
plt.ylabel('Sales (%)')

# Adding title to the chart
plt.title('Total Sales by customer segments (%)')

# Adding percentages as text labels on top of bars with slight adjustment for positioning
# Selecting top 10 values
top_segment = segment_sales.nlargest(10)
for i, v in enumerate(top_segment):
    plt.text(i, v + 0.001, f"{v:.1f}%", ha='center', va='bottom', fontsize=10)
plt.xticks(rotation=20, ha='right')


# Subplot 2:Segment vs Profit Margin (Line)
# Positioning subplot at row 2, column 2, position 3
plt.subplot(2, 2, 3)

# Aggregate based on categories, sort by descending order and select top 10 values
segment_profit = df.groupby('Segment')['Profit Margin'].mean().sort_values(ascending=False)

# Converting to percentage
segment_profit = segment_profit / segment_profit.sum() * 100

# Creating line chart with annotations
plt.plot(segment_profit.index, segment_profit, color='green', label='Profit')

# Creating scatter plot to overalp on chart
plt.scatter(segment_profit.index, segment_profit.values, color='red', alpha=0.5)

# Plotting horizontal line represting average value
plt.axhline(y=(segment_profit.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Segment')
plt.ylabel('Average Profit Margin (in%)')

# Adding title to the chart
plt.title('Average Profit Margin by customer segments (in%)')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Subplot 3: Segment vs Quantity (Line)
# Positioning subplot at row 2, column 2, position 2
plt.subplot(2, 2, 2)

# Aggregate based on categories, sort by descending order and select top 10 values
segment_quantity = df.groupby('Segment')['Quantity'].mean().sort_values(ascending=False)

# Creating line chart with annotations
plt.plot(segment_quantity.index, segment_quantity, color='purple', label='Quantity (mean)')

# Creating scatter plot to overalp on chart
plt.scatter(segment_quantity.index, segment_quantity.values, color='red', alpha=0.5)

# Plotting horizontal line represting average value
plt.axhline(y=(segment_quantity.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Segment')
plt.ylabel('Average Quantity')

# Adding title to the chart
plt.title('Average Quantity by customer segments')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding legend to the chart
plt.legend()

# Adjusting space between chart
plt.tight_layout()

# Displaying the graph
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Sales by Customer Segments (%): Consumers sales have conributed over 52%, followed by corporate and home office </span></li>
# <li ><span style="color: #808080;">Average Profit Margin by Customer Segments(%): Profit margin stands in positive range from 30 to 35%</span></li>
# <li ><span style="color: #808080;">Average Quantity by Customer Segments: Average quantity is nearly 4 units </span></li>
# </ul>

# %%
# Split by Category

# Setting figure size for readability
plt.figure(figsize=(16, 10))

# Subplot 1:Category vs Sales (Bar Graph)
# Positioning subplot at row 2, column 2, position 1
plt.subplot(2, 2, 1)

# Aggregate based on categories
Category_sales = df.groupby('Category')['Sales'].sum().sort_values(ascending=False).head(10)

# Converting to percentage
Category_sales = Category_sales / Category_sales.sum() * 100

# Creating bar chart with annotations
plt.bar(Category_sales.index, Category_sales, color='#F5E180')

# Plotting horizontal line represting average value
plt.axhline(y=(Category_sales.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Category')
plt.ylabel('Sales (%)')

# Adding title to the chart
plt.title('Total Sales by product category (%)')

# Adding percentages as text labels on top of bars with slight adjustment for positioning
# Selecting bottom 10 values
top_Category = Category_sales.nlargest(10)
for i, v in enumerate(top_Category):
    plt.text(i, v + 0.01, f"{v:.1f}%", ha='center', va='bottom', fontsize=10)

# Rotating x-axis labels for better readability
plt.xticks(rotation=20, ha='right')


# Subplot 2:Category vs Profit Margin (Line)
# Positioning subplot at row 2, column 2, position 3
plt.subplot(2, 2, 3)

# Aggregate based on categories
Category_profit = df.groupby('Category')['Profit Margin'].mean().sort_values(ascending=False).head(10)

# Converting to percentage
Category_profit = Category_profit / Category_profit.sum() * 100

# Creating line chart with annotations
plt.plot(Category_profit.index, Category_profit, color='green', label='Profit')

# Creating scatter plot to overalp on chart
plt.scatter(Category_profit.index, Category_profit.values, color='red', alpha=0.5)

# Plotting horizontal line represting average value
plt.axhline(y=(Category_profit.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Category')
plt.ylabel('Average Profit Margin (in%)')

# Adding title to the chart
plt.title('Average Profit Margin by product category (in%)')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Subplot 3: Category vs Quantity (Line)
# Positioning subplot at row 2, column 2, position 2
plt.subplot(2, 2, 2)

# Aggregate based on categories
Category_quantity = df.groupby('Category')['Quantity'].mean().sort_values(ascending=False).head(10)

# Creating line chart with annotations
plt.plot(Category_quantity.index, Category_quantity, color='purple', label='Quantity (mean)')

# Creating scatter plot to overalp on chart
plt.scatter(Category_quantity.index, Category_quantity.values, color='red', alpha=0.5)

# Plotting horizontal line represting average value
plt.axhline(y=(Category_quantity.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Category')
plt.ylabel('Average Quantity')

# Adding title to the chart
plt.title('Average Quantity by product category')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding legend to the chart
plt.legend()

# Adjusting space between chart
plt.tight_layout()

# Displaying the graph
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Sales by Customer Product category (%): Technology have contributed over 37%, followed by office supplies and furniture </span></li>
# <li ><span style="color: #808080;">Average Profit Margin by Product category(%): Average Profit margin equates to ~35%, of which office supplies stands at 55% margin</span></li>
# <li ><span style="color: #808080;">Average Quantity by Product category: Average quantity is nearly 4 units </span></li>
# </ul>

# %%
# Split by Sub-Category

# Setting figure size for readability
plt.figure(figsize=(16, 10))

# Subplot 1:Sub-Category vs Sales (Bar Graph)
# Positioning subplot at row 2, column 2, position 1
plt.subplot(2, 2, 1)

# Aggregate based on categories
sub_Category_sales = df.groupby('Sub-Category')['Sales'].sum().sort_values(ascending=False).head(10)

# Converting to percentage
sub_Category_sales = sub_Category_sales / sub_Category_sales.sum() * 100

# Creating bar chart with annotations
plt.bar(sub_Category_sales.index, sub_Category_sales, color='#BEADFA')

# Plotting horizontal line represting average value
plt.axhline(y=(sub_Category_sales.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Sub-Category')
plt.ylabel('Sales (%)')

# Adding title to the chart
plt.title('Total Sales by product Sub-Category (%)')

# Adding percentages as text labels on top of bars with slight adjustment for positioning
# Selecting bottom 10 values
top_sub_Category = sub_Category_sales.nlargest(10)
for i, v in enumerate(top_sub_Category):
    plt.text(i, v + 0.001, f"{v:.1f}%", ha='center', va='bottom', fontsize=10)
plt.xticks(rotation=20, ha='right')


# Subplot 2:Sub-Category vs Profit Margin (Line)
# Positioning subplot at row 2, column 2, position 3
plt.subplot(2, 2, 3)

# Aggregate based on categories
sub_Category_profit = df.groupby('Sub-Category')['Profit Margin'].mean().sort_values(ascending=False).head(10)

# Converting to percentage
sub_Category_profit = sub_Category_profit / sub_Category_profit.sum() * 100

# Creating line chart with annotations
plt.plot(sub_Category_profit.index, sub_Category_profit, color='green', label='Profit')

# Creating scatter plot to overalp on chart
plt.scatter(sub_Category_profit.index, sub_Category_profit.values, color='red', alpha=0.5)

# Plotting horizontal line represting average value
plt.axhline(y=(sub_Category_profit.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Sub-Category')
plt.ylabel('Average Profit Margin (in%)')

# Adding title to the chart
plt.title('Average Profit Margin by product Sub-Category (in%)')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Subplot 3: Sub-Category vs Quantity (Line)
# Positioning subplot at row 2, column 2, position 2
plt.subplot(2, 2, 2)

# Aggregate based on categories
sub_Category_quantity = df.groupby('Sub-Category')['Quantity'].mean().sort_values(ascending=False).head(10)

# Creating line chart with annotations
plt.plot(sub_Category_quantity.index, sub_Category_quantity, color='purple', label='Quantity (mean)')

# Creating scatter plot to overalp on chart
plt.scatter(sub_Category_quantity.index, sub_Category_quantity.values, color='red', alpha=0.5)

# Plotting horizontal line represting average value
plt.axhline(y=(Category_quantity.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Sub-Category')
plt.ylabel('Average Quantity')

# Adding title to the chart
plt.title('Average Quantity by product Sub-Category')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding legend to the chart
plt.legend()

# Adjusting space between chart
plt.tight_layout()

# Displaying the graph
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Sales by Customer Product sub-category (%): Bookcases, Copiers, Phones, Storage and Appliance, contribute to ~65% </span></li>
# <li ><span style="color: #808080;">Average Profit Margin by Product sub-category(%): Average Profit margin equates to 10%, ranging from 7.5 to 11.5% profit margin</span></li>
# <li ><span style="color: #808080;">Average Quantity by Product sub-category: Average quantity is nearly 4 units </span></li>
# </ul>

# %%
# Split by Shipping mode

# Setting figure size for better readability
plt.figure(figsize=(16, 10))

# Subplot 1:Ship Mode vs Sales (Bar Graph)
# Positioning subplot at row 2, column 2, position 1
plt.subplot(2, 2, 1)

# Aggregate based on categories, sort by descending order and select top 10 values
ship_sales = df.groupby('Ship Mode')['Sales'].sum().sort_values(ascending=False).head(10)

# Converting to percentage
ship_sales = ship_sales / ship_sales.sum() * 100

# Creating bar chart with annotations
plt.bar(ship_sales.index, ship_sales, color='#CE7BB0')

# Plotting horizontal line represting average value
plt.axhline(y=(ship_sales.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Ship Mode')
plt.ylabel('Sales (%)')

# Adding title to the chart
plt.title('Total Sales by Ship Mode (%)')

# Adding percentages as text labels on top of bars with slight adjustment for positioning
# Selecting bottom 10 values
top_ship = ship_sales.nlargest(10)
for i, v in enumerate(top_ship):
    plt.text(i, v + 0.01, f"{v:.1f}%", ha='center', va='bottom', fontsize=10)
plt.xticks(rotation=20, ha='right')


# Subplot 2:Ship Mode vs Profit Margin (Line)
# Positioning subplot at row 2, column 2, position 3
plt.subplot(2, 2, 3)

# Aggregate based on categories, sort by descending order and select top 10 values
ship_profit = df.groupby('Ship Mode')['Profit Margin'].mean().sort_values(ascending=False).head(10)

# Converting to percentage
ship_profit = ship_profit / ship_profit.sum() * 100

# Creating line chart with annotations
plt.plot(ship_profit.index, ship_profit, color='#7469B6', label='Profit')

# Creating scatter plot to overalp on chart
plt.scatter(ship_profit.index, ship_profit.values, color='red', alpha=0.5)

# Plotting horizontal line represting average value
plt.axhline(y=(ship_profit.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Ship Mode')
plt.ylabel('Average Profit Margin (in%)')

# Adding title to the chart
plt.title('Average Profit Margin by Ship Mode (in%)')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Subplot 3: Ship Mode vs Quantity (Line)
# Positioning subplot at row 2, column 2, position 2
plt.subplot(2, 2, 2)

# Aggregate based on categories, sort by descending order and select top 10 values
ship_quantity = df.groupby('Ship Mode')['Quantity'].mean().sort_values(ascending=False).head(10)

# Creating line chart with annotations
plt.plot(ship_quantity.index, ship_quantity, color='purple', label='Quantity (mean)')

# Creating scatter plot to overalp on chart
plt.scatter(ship_quantity.index, ship_quantity.values, color='red', alpha=0.5)

# Plotting horizontal line represting average value
plt.axhline(y=(ship_quantity.values.mean()), color='gray', linestyle='dashed', linewidth=0.8)

# Adding labels to the chart
plt.xlabel('Ship Mode')
plt.ylabel('Average Quantity')

# Adding title to the chart
plt.title('Average Quantity by Ship Mode')

# Rotating x-axis labels for better readability
plt.xticks(rotation=45, ha='right')

# Adding legend to the chart
plt.legend()

# Adjusting space between chart
plt.tight_layout()

# Displaying the graph
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Sales by Customer Product ship mode (%): Economy is the most preferred shipping mode followed by economy plus, priority and immediate </span></li>
# <li ><span style="color: #808080;">Average Profit Margin by Product ship mode(%): Average Profit margin equates to 25%, ranging from 20 to 30% profit margin</span></li>
# <li ><span style="color: #808080;">Average Quantity by Product ship mode: Average quantity is nearly 4 units </span></li>
# </ul>

# %% [markdown]
# <h3><span style="color: #808080;">5.4.2 Address operational inefficiencies and customer engagement issues in underperforming areas</span></h3>

# %%
# Region vs Countries

# Printing a descriptive message to indicate the output
print("Sales percentage by Region vs Countries:")

# Creating a contingency table
Regions_country = pd.crosstab([df['Region']], 
                         [df['Country']], 
                         values=df['Sales'], 
                         aggfunc='count', normalize="index")*100

# Displaying the table with background gradient styling for better readability
display(Regions_country.style.background_gradient(cmap= "Accent"))
# Out:
# Sales percentage by Region vs Countries:
# <style type="text/css">
# #T_ee117_row0_col0, #T_ee117_row0_col1, #T_ee117_row0_col4, #T_ee117_row0_col5, #T_ee117_row0_col8, #T_ee117_row0_col13, #T_ee117_row1_col2, #T_ee117_row1_col3, #T_ee117_row1_col6, #T_ee117_row1_col9, #T_ee117_row1_col12, #T_ee117_row1_col14, #T_ee117_row2_col7, #T_ee117_row2_col10, #T_ee117_row2_col11 {
#   background-color: #666666;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Region vs Countries: Underperforming countries (Sales less than 5%) are Belgium, Switzerland, Denmark, Finland, Norway and Portugal </span></li>
# </ul>

# %%
# Countries vs State

# Printing a descriptive message to indicate the output
print("Sales percentage by Countries vs State:")

# Set of 6 colors
colors = ["#DD8968", "#FFCA61", "#C9F0D6", "#FAFCB4", "#C6C5B3", "#E6E6E6"]

# Creating a contingency table
State_country = pd.crosstab([df['Country']], 
                         [df['State']], 
                         values=df['Sales'], 
                         aggfunc='count', normalize="index")*100

# Defining countries to filter
countries_to_filter = ["Belgium", "Switzerland", "Denmark", "Finland", "Norway", "Portugal"]

# Creating a figure for subplots (we could adjust figsize as needed)
fig, axes = plt.subplots(2, 3, figsize=(13, 10))  # 2 rows, 3 columns

# Iterating through countries and subplots
for i, country in enumerate(countries_to_filter):
    # Filter data for the current country
    filtered_data = State_country.loc[country][State_country.loc[country] > 0]
    filtered_data = filtered_data.sort_values(ascending=True)

    # Converting to DataFrame and set column name
    filtered_data = filtered_data.to_frame()
    filtered_data.columns = ["Sales Percentage"]

    # Getting the current subplot (axes[row_index, column_index]) based on iteration index
    ax = axes[i // 3, i % 3]

    # Plotting the bar chart
    filtered_data.plot(kind='bar', ax=ax, color = colors[i], legend=False)

    # Adding x and y labels
    ax.set_ylabel('Sales Percentage')

    # Adding percentage labels on top of bars with adjusted vertical placement
    for p in ax.patches:
        ax.text(p.get_x() + p.get_width() / 2, p.get_height() + 0.01, '{:.2f}%'.format(p.get_height()),
                ha='center', va='bottom', fontsize=10)

    # Make X-axis rotation
    plt.xticks(rotation=20, ha='right')

    # Setting subplot title
    ax.set_title(country)

# Adjusting space between chart
plt.tight_layout()

# Displaying the graph
plt.show()
# Out:
# Sales percentage by Countries vs State:

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Countries vs State: Underperforming counties are taken to deep dive to understand low performing states</span></li>
#  <ul>
#     <li ><span style="color: #808080;">Under performing states (Sales less than 5%) in Belgium are, Liège, Brussels, West Flanders</span></li>
#     </ul>
#     <ul>
#     <li ><span style="color: #808080;">Under performing states (Sales less than 5%) in Switzerland is, St. Gallen</span></li>
#     </ul>
#     <ul>
#     <li ><span style="color: #808080;">Under performing states (Sales less than 5%) in Denmark are, Central Jutland, Zealand </span></li>
#     </ul>
#     <ul>
#     <li ><span style="color: #808080;">Under performing states (Sales less than 5%) in Finland is Kymenlaakso </span></li>
#     </ul>
#     <ul>
#     <li ><span style="color: #808080;">Under performing states (Sales less than 5%) in Norway are Hedmark, Vest-Agder</span></li>
#     </ul>
#     <ul>
#     <li ><span style="color: #808080;">Under performing states (Sales less than 5%) in Portugal are Aveiro, Setúbal, Braga</span></li>
#     </ul>
#     <ul>
# </ul>

# %%
# State vs City

# Printing a descriptive message to indicate the output
print("Sales percentage by State vs City:")

# Creating a contingency table
State_city = pd.crosstab([df['State']], 
                          [df['City']], 
                          values=df['Sales'], 
                          aggfunc='count', normalize="index")*100

# DefDefiningine cities to filter
cities_to_filter = ["Liège", "Brussels", "West Flanders", "St. Gallen", "Central Jutland", "Zealand", "Kymenlaakso", "Hedmark", "Vest-Agder", "Aveiro", "Setúbal", "Braga"]

# list of 12 colors
colors = ['#F7DCB9', '#AFD198', '#AD88C6', '#F3D7CA', '#AAD7D9', '#F9F9E0', '#D6C7AE', '#DFCCFB', '#AAC8A7', '#F5F0BB', '#C7E9B0', '#F0DBDB']

# Creating a figure for subplots
fig, axes = plt.subplots(4, 3, figsize=(16, 19))  # Adjust figure size for better readability

# Iterating through cities and subplots
for i, state in enumerate(cities_to_filter):
  # Filter data for the current city
  filtered_data_s = State_city.loc[state][State_city.loc[state] > 0]
  filtered_data_s = filtered_data_s.sort_values(ascending=True)

  # Converting to DataFrame and set column name
  filtered_data_s = filtered_data_s.to_frame()
  filtered_data_s.columns = ["Sales Percentage"]

  # Getting the current subplot (axes[row_index, column_index]) based on iteration index
  ax = axes[i // 3, i % 3]

  # Plotting the bar chart with color customization
  filtered_data_s.plot(kind='bar', ax=ax, legend=False, color=colors[i])

  # Adding x and y labels with adjusted spacing
  ax.set_xlabel('City', labelpad=10)  # Add padding between label and axis
  ax.set_ylabel('Sales Percentage', labelpad=10)

  # Adding percentage labels on top of bars with adjusted vertical placement
  for p in ax.patches:
    ax.text(p.get_x() + p.get_width() / 2, p.get_height() - 0.01, '{:.2f}%'.format(p.get_height()),
            ha='center', va='bottom', fontsize=10)

  # Setting subplot title
  ax.set_title(cities_to_filter[i])

# Adjusting space between chart
plt.tight_layout()

# Displaying the graph
plt.show()
# Out:
# Sales percentage by State vs City:

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">State vs City: We notice that majority of underperforming states has only one branch in cityto cater to customer </span></li>
# <ul>
# <li ><span style="color: #808080;">States with 2 cities are Liège, Braga</span></li>
# <li ><span style="color: #808080;">States with 3 cities is West Flanders</span></li>
# </ul>
# </ul>

# %% [markdown]
# <h3><span style="color: #808080;">5.4.3 Optimizing Discounts & Shipping Modes</span></h3>

# %%
# Printing a descriptive message to indicate the output
print("Profit margin vs Discount percentage:")

# Grouping by Ship Mode and calculate profitability metrics
ship_mode_analysis = df.groupby('Ship Mode')[['Profit Margin', "Discount Percentage"]].mean()

# Creating the bar chart
ship_mode_analysis.plot(kind='bar', figsize=(15, 6), color=["#9EB23B", "#BBC3A4"])
plt.xlabel('Ship Mode')

# Add labels on top of bars with adjusted positioning
for i, v in enumerate(ship_mode_analysis['Profit Margin']):
    plt.text(i, v, f'{v:.2f}', ha='center', va='bottom')
    plt.text(i, ship_mode_analysis['Discount Percentage'][i], f'{ship_mode_analysis["Discount Percentage"][i]:.2f}', ha='center', va='bottom')
plt.subplots_adjust(bottom=0.2)

# Setting Y limit
plt.ylim(7.5, 12.8)

# Rotating x-axis labels for readability
plt.xticks(rotation=45, ha='right')

# Setting y label, title
plt.ylabel('Profitability Metrics')
plt.legend(['Profit Margin', 'Discount Percentage'])

# Display the output
plt.show()
# Out:
# Profit margin vs Discount percentage:

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Profit margin vs Discount percentage: </span></li>
# <ul>
# <li ><span style="color: #808080;">We could see that there is inverse relation among Discount percentage and Profit margin in Economy, Economy plus and priority mode</span></li>
# <li ><span style="color: #808080;">In Immediate shipping mode, Discount is at lower side compared to profit margin, this could be because customers are willing pay more for quick product delivery</span></li>
# </ul>
# </ul>

# %%
# Discount vs Sales Vs Profit Margin and Quantity
print("Sales, Profit, and Quantity by Discount Percentage:")

# Create table with aggregation
discount_analysis = df.groupby(['Discount']).agg({'Sales':'mean', 'Profit':'mean','Quantity':'sum'}).reset_index()
discount_analysis

# Creating the figure
fig, axes = plt.subplots(nrows=3, sharex=True, figsize=(10, 6))  # 3 rows to accommodate 3 columns

# Extracting data for each column
discount = discount_analysis['Discount']
sales = discount_analysis['Sales']
profit = discount_analysis['Profit']
quantity = discount_analysis['Quantity']

# Defining color palette
# colors = ['blue', 'green', 'red']  # Customize these colors as desired
colors = sns.color_palette('tab10')

# Plotting Sales on the first subplot
axes[0].plot(discount, sales, marker='o', color=colors[0], label='Sales')
# Plot average discount line
average_sales = sales.mean()
axes[0].axhline(y=average_sales, color='#7F27FF', linestyle='dashed', linewidth=0.8, label='Average Sales')
axes[0].set_ylabel('Sales (mean)', color=colors[0])  # Match label color
axes[0].legend()

# Plotting Profit on the second subplot
axes[1].plot(discount, profit, marker='o', color=colors[1], label='Profit')
axes[1].axhline(y=0, color='#7F27FF', linestyle='dashed', linewidth=0.8, label='Origin')  # Baseline for profit
axes[1].set_ylabel('Profit (mean)', color=colors[1])  # Match label color
axes[1].set_ylim([-2000, 1000])
axes[1].legend()  # Consider adding a title for y-axis (e.g., 'Profit (mean)')

# Plotting Quantity on the third subplot
axes[2].plot(discount, quantity, marker='o', color=colors[2], label='Quantity')
axes[2].axhline(y=0, color='#7F27FF', linestyle='dashed', linewidth=0.8, label='Origin')  # Baseline for profit
axes[2].set_ylabel('Quantity (sum)', color=colors[2])  # Match label color
axes[2].set_xlabel('Discount Percentage')
axes[2].set_ylim([-5000, 20000])
axes[2].legend()


# Setting title and adjust layout
plt.suptitle('Sales, Profit, and Quantity by Discount Percentage')

# Fit the graphs by adjusting white spaces
plt.tight_layout()

# Displaying the chart
plt.show()
# Out:
# Sales, Profit, and Quantity by Discount Percentage:

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Sales by Discount Percentage: Average sales stands at USD 500. Discount of 15%, 35%, 45%, 70% and 85% are having above average sales</span></li>
# <li ><span style="color: #808080;">Profit margin by Discount Percentage: Average profit margin goes on decreasing as discount increases, when discount are more than 20% profit goes negative</span></li>
# <li ><span style="color: #808080;">Quantity by Discount Percentage:When discount is from 0 to 20%, the sold quantity is higher compared to rest of discount offered</span></li>
# </ul>

# %% [markdown]
# <h3><span style="color: #808080;">5.4.4 Feedback Analysis</span></h3>

# %%
# Getting the number of categories in variable
feedback_counts = df['Feedback'].value_counts()

# Creating pie chart
# Adjusting figure size for better readability
plt.figure(figsize=(3, 3))

# Creating the pie chart
plt.pie(feedback_counts, labels=feedback_counts.index, autopct="%1.1f%%")

# Adding title to the chart
plt.title("Distribution of feedback provided on purchase")

# Displaying the chart
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Almost half of the customers have provided feedback on purchase</span></li>
#
# </ul>

# %%
feedback_analysis = df.groupby(['Feedback']).agg({'Sales':'mean', 'Profit':'mean','Quantity':'sum'})

# Creating separate subplots for each column
fig, axes = plt.subplots(nrows=1, ncols=3, figsize=(12, 5))  # 1 row, 3 columns for better visibility

# Extracting data for each column
feedback = feedback_analysis.index.to_numpy()  # Assuming 'Feedback' is the index
sales = feedback_analysis['Sales']
profit = feedback_analysis['Profit']
quantity = feedback_analysis['Quantity']

# Plotting Sales on the first subplot
axes[0].bar(feedback, sales, color='skyblue', label='Sales (mean)')
axes[0].set_xlabel('Feedback Category')
axes[0].set_ylabel('Sales (mean)')
axes[0].set_title('Sales by Feedback')
axes[0].legend(loc=3)

#Adding anootation value on bars
for i, v in enumerate(sales.round(2)):
    axes[0].text(i, v, str(v), color='black', va='bottom', fontweight='bold')

# Plotting Profit on the second subplot
axes[1].bar(feedback, profit, color='lightgreen', label='Profit (mean)')
axes[1].set_xlabel('Feedback Category')
axes[1].set_ylabel('Profit (mean)')
axes[1].set_title('Profit by Feedback')
axes[1].legend(loc=3)

#Adding anootation value on bars
for i, v in enumerate(profit.round(2)):
    axes[1].text(i, v, str(v), color='black', va='bottom', fontweight='bold')

# Plotting Quantity on the third subplot
axes[2].bar(feedback, quantity, color='gold', label='Quantity (sum)')
axes[2].set_xlabel('Feedback Category')
axes[2].set_ylabel('Quantity (sum)')
axes[2].set_title('Quantity by Feedback')
axes[2].legend(loc=3)

#Adding anootation value on bars
for i, v in enumerate(quantity.round(2)):
    axes[2].text(i, v, str(v), color='black', va='bottom', fontweight='bold')


# Fit the graphs by adjusting white spaces
plt.tight_layout()

# Displaying the chart
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">We see that there is almost equal distribution of feedback provided among sales, profit and quantity</span></li>
#
# </ul>

# %%
# Getting product names and feedback counts
product_names_feedback = df.groupby(['Product Name'])['Feedback'].count().sort_values(ascending=False).head(10)
feedback_counts = product_names_feedback.values

# Creating the figure and setting its size
plt.figure(figsize=(10, 6))

# Plot the bar graph
plt.bar(product_names_feedback.index, feedback_counts, color='#C9F0D6')

# Setting the labels and title
plt.xlabel('Feedback Count')
plt.ylabel('Product Name')
plt.title('Top 10 Products by Feedback Count')

# Rotating x-axis labels for readability
plt.xticks(rotation=45, ha='right')  
# plt.gca().invert_yaxis()  # Invert y-axis for readability

# Adding annotations on the bar
for i, v in enumerate(feedback_counts):
    plt.text(i, v, str(v), ha='center', va='bottom')


# Fit the graph by adjusting white spaces
plt.tight_layout()

# Displaying the chart
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Products which received feedback on purchase are: </span></li>
# <ul>
# <li ><span style="color: #808080;">Eldon File Cart, Single Width is the most feedback received product, followed by Rogers File Cart, Stanley Pencil Sharpener, Sanford Pencil Sharpener... and so on</span></li>
# </ul>
# </ul>

# %%
# Filtering data for TRUE and FALSE feedback
true_feedback = df[df['Feedback'] == 'TRUE']
false_feedback = df[df['Feedback'] == 'FALSE']

# Getting top 10 products with TRUE feedback 
top_true_feedback = (true_feedback.groupby(['Product Name'])['Feedback'].count().sort_values(ascending=False).head(10))
product_names_true = top_true_feedback.index
true_feedback_counts = top_true_feedback.values

# Getting top 10 products with FALSE feedback
top_false_feedback = (false_feedback.groupby(['Product Name'])['Feedback'].count().sort_values(ascending=False).head(10))
product_names_false = top_false_feedback.index
false_feedback_counts = top_false_feedback.values


# Creating subplots for TRUE and FALSE feedback
fig, axes = plt.subplots(nrows=2, ncols=1, figsize=(12, 12))

# Plotting TRUE feedback on the first subplot
axes[0].bar(product_names_true, true_feedback_counts, color='#D0EF84', label='TRUE Feedback', width=0.8)
axes[0].set_xlabel('Product Name')
axes[0].set_ylabel('TRUE Feedback Count')
axes[0].set_title('Top 10 Products with TRUE Feedback')
axes[0].legend()
axes[0].tick_params(axis='x', rotation=45)

# Show annotation on bar
for i, v in enumerate(true_feedback_counts):
    axes[0].annotate(str(v), xy=(i, v), va='bottom', ha='center')

# Plotting FALSE feedback on the second subplot
axes[1].bar(product_names_false, false_feedback_counts, color='#F4D143', label='FALSE Feedback')
axes[1].set_xlabel('Product Name')
axes[1].set_ylabel('FALSE Feedback Count')
axes[1].set_title('Top 10 Products with FALSE Feedback')
axes[1].legend()
plt.xticks(rotation=45, ha='right')  # Rotate x-axis labels for readability (if many names)

# Show annotation on bar
for i, v in enumerate(false_feedback_counts):
    axes[1].annotate(str(v), xy=(i, v), va='bottom', ha='center')

# Fit the graph by adjusting white spaces
plt.tight_layout()

# Displaying the chart
plt.show()

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Top Products with True Feedback</span></li>
# <ul>
# <li ><span style="color: #808080;">Eldon File Cart, Nokia Smartphone, Sanford Pencil Sharpener are the top 3 most products received True Feedback</span></li>
# </ul>
# </ul>
#
# <ul>
# <li ><span style="color: #808080;">Top Products with False Feedback</span></li>
# <ul>
# <li ><span style="color: #808080;">Rogers File Cart, Avery Index Tab, Stanley Pencil Sharpener are the top 3 most products received False Feedback</span></li>
# </ul>
# </ul>

# %% [markdown]
# <h3><span style="color: #808080;">5.4.5 Improving Product Mix</span></h3>

# %%
# Create table with aggregation
top_selling_products = (df.groupby('Product Name')['Sales'].sum().sort_values(ascending=False).head(10))  # Adjust the number of top products as needed

# Convert to data frame for applying style
top_selling_products_df = top_selling_products.to_frame(name='Sales').reset_index()

# Display the output
print("\nTop 10 Most product sales by value:")

# Apply background gradient
display(top_selling_products_df.style.background_gradient(cmap= "crest")) # Highlight cells based on values
# Out:
# Top 10 Most product sales by value:
# <style type="text/css">
# #T_fc3f6_row0_col1 {
#   background-color: #2c3172;
#   color: #f1f1f1;
# }
# #T_fc3f6_row1_col1 {
#   background-color: #58a590;
#   color: #f1f1f1;
# }
# #T_fc3f6_row2_col1 {
#   background-color: #72b490;
#   color: #f1f1f1;
# }
# #T_fc3f6_row3_col1 {
#   background-color: #7eba91;
#   color: #000000;
# }
# #T_fc3f6_row4_col1 {
#   background-color: #88bf91;
#   color: #000000;
# }
# #T_fc3f6_row5_col1 {
#   background-color: #8dc191;
#   color: #000000;
# }
# #T_fc3f6_row6_col1 {
#   background-color: #90c391;
#   color: #000000;
# }
# #T_fc3f6_row7_col1 {
#   background-color: #92c491;
#   color: #000000;
# }
# #T_fc3f6_row8_col1 {
#   background-color: #9fca91;
#   color: #000000;
# }
# #T_fc3f6_row9_col1 {
#   background-color: #a5cd90;
#   color: #000000;
# }
# </style>
# <table id="T_fc3f6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
# ...

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Top most sales by value are:</span></li>
# <ul>
# <li ><span style="color: #808080;">Nokia Smartphone, Hamilton Beach Stove, Cisco Smartphones are the top 3 most sales by value products</span></li>
# </ul>
# </ul>
#
# </ul>

# %%
# Create table with aggregation, sort the values and select top 10
customer_frequency = df.groupby('Customer Name')['Order ID'].count().sort_values(ascending=False).head(10)

# Convert to data frame for applying style
customer_frequency_df = customer_frequency.to_frame(name='Number of orders').reset_index()

# Display the output
print("\nTop 10 Most Frequent Customers:")

# Apply background gradient
display(customer_frequency_df.style.background_gradient(cmap= "summer_r")) # Highlight cells based on values
# Out:
# Top 10 Most Frequent Customers:
# <style type="text/css">
# #T_87dc1_row0_col1 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_87dc1_row1_col1 {
#   background-color: #49a466;
#   color: #f1f1f1;
# }
# #T_87dc1_row2_col1 {
#   background-color: #6db666;
#   color: #f1f1f1;
# }
# #T_87dc1_row3_col1 {
#   background-color: #92c866;
#   color: #000000;
# }
# #T_87dc1_row4_col1, #T_87dc1_row5_col1 {
#   background-color: #b6db66;
#   color: #000000;
# }
# #T_87dc1_row6_col1, #T_87dc1_row7_col1, #T_87dc1_row8_col1 {
#   background-color: #dbed66;
#   color: #000000;
# }
# #T_87dc1_row9_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# </style>
# <table id="T_87dc1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_87dc1_level0_col0" class="col_heading level0 col0" >Customer Name</th>
#       <th id="T_87dc1_level0_col1" class="col_heading level0 col1" >Number of orders</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
# ...

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Top most loyal customers:</span></li>
# <ul>
# <li ><span style="color: #808080;">Joel Peters, Jose Gambino, Isaac David are the top 3 most loyal customers</span></li>
# </ul>
# </ul>
#
# </ul>

# %%
# Create table with aggregation, sort the values and select top 10
top_selling_by_profit_margin = df.groupby('Product Name')['Profit Margin'].mean().sort_values(ascending=False).head(10)

# Convert to data frame for applying style
top_selling_by_profit_margin_df = top_selling_by_profit_margin.to_frame(name='Number of orders').reset_index()
top_selling_by_profit_margin_df=top_selling_by_profit_margin_df.round(1)

# Display the output
print("\nTop 10 Most Profitable Products:")

# Apply background gradient
display(top_selling_by_profit_margin_df.style.background_gradient(cmap= "cividis")) # Highlight cells based on values
# Out:
# Top 10 Most Profitable Products:
# <style type="text/css">
# #T_b1fbe_row0_col1, #T_b1fbe_row1_col1 {
#   background-color: #fee838;
#   color: #000000;
# }
# #T_b1fbe_row2_col1, #T_b1fbe_row3_col1, #T_b1fbe_row4_col1, #T_b1fbe_row5_col1, #T_b1fbe_row6_col1, #T_b1fbe_row7_col1 {
#   background-color: #948e77;
#   color: #f1f1f1;
# }
# #T_b1fbe_row8_col1 {
#   background-color: #666970;
#   color: #f1f1f1;
# }
# #T_b1fbe_row9_col1 {
#   background-color: #00224e;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_b1fbe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b1fbe_level0_col0" class="col_heading level0 col0" >Product Name</th>
#       <th id="T_b1fbe_level0_col1" class="col_heading level0 col1" >Number of orders</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1fbe_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1fbe_row0_col0" class="data row0 col0" >Deflect-O Light Bulb, Erganomic</td>
# ...

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Top most Profitable Products:</span></li>
# <ul>
# <li ><span style="color: #808080;">Deflect-O Light Bulb, OIC Clamp, Ikea Stackable Book rack, Jiffy Mailers, HP Copy Machine, Hon File Folder Labels, Epson Receipt Printer are the top most profitable products with average profit margin by 50%</span></li>
# </ul>
# </ul>
# </ul>

# %%
# Create table with aggregation, sort the values and select top 10
top_selling_category_by_profit_margin = df.groupby('Category')['Profit Margin'].mean().sort_values(ascending=False).head(10)

# Convert to data frame for applying style
top_selling_category_by_profit_margin_df = top_selling_category_by_profit_margin.to_frame(name='Profit Margin').reset_index()
top_selling_category_by_profit_margin_df = top_selling_category_by_profit_margin_df.round(1)

# Display the output
print("\nTop Most Profitable Category:")

# Apply background gradient
display(top_selling_category_by_profit_margin_df.style.background_gradient(cmap= "Paired")) # Highlight cells based on values
# Out:
# Top Most Profitable Category:
# <style type="text/css">
# #T_3c758_row0_col1 {
#   background-color: #b15928;
#   color: #f1f1f1;
# }
# #T_3c758_row1_col1 {
#   background-color: #fb9a99;
#   color: #000000;
# }
# #T_3c758_row2_col1 {
#   background-color: #a6cee3;
#   color: #000000;
# }
# </style>
# <table id="T_3c758">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3c758_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_3c758_level0_col1" class="col_heading level0 col1" >Profit Margin</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3c758_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3c758_row0_col0" class="data row0 col0" >Office Supplies</td>
#       <td id="T_3c758_row0_col1" class="data row0 col1" >12.600000</td>
#     </tr>
#     <tr>
#       <th id="T_3c758_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Top Profitable Category:</span></li>
# <ul>
# <li ><span style="color: #808080;">Office supplies is the top most category which is most profitable, followed by technology and Furniture</span></li>
# </ul>
# </ul>

# %%
# Create table with aggregation, sort the values and select top 10
top_selling_sub_category_by_profit_margin = df.groupby('Sub-Category')['Profit Margin'].mean().sort_values(ascending=False)

# Convert to data frame for applying style
top_selling_sub_category_by_profit_margin_df = top_selling_sub_category_by_profit_margin.to_frame(name='Profit Margin').reset_index()
top_selling_sub_category_by_profit_margin_df = top_selling_sub_category_by_profit_margin_df.round(1)

# Display the output
print("\n Profitable Sub-Category:")

# Apply background gradient
display(top_selling_sub_category_by_profit_margin_df.style.background_gradient(cmap= "Spectral")) # Highlight cells based on values
# Out:
#  Profitable Sub-Category:
# <style type="text/css">
# #T_d98d6_row0_col1, #T_d98d6_row1_col1 {
#   background-color: #5e4fa2;
#   color: #f1f1f1;
# }
# #T_d98d6_row2_col1 {
#   background-color: #5956a5;
#   color: #f1f1f1;
# }
# #T_d98d6_row3_col1 {
#   background-color: #545ca8;
#   color: #f1f1f1;
# }
# #T_d98d6_row4_col1 {
#   background-color: #525fa9;
#   color: #f1f1f1;
# }
# #T_d98d6_row5_col1 {
#   background-color: #5061aa;
#   color: #f1f1f1;
# }
# #T_d98d6_row6_col1 {
#   background-color: #496aaf;
#   color: #f1f1f1;
# }
# #T_d98d6_row7_col1 {
#   background-color: #486cb0;
#   color: #f1f1f1;
# }
# #T_d98d6_row8_col1 {
#   background-color: #3682ba;
#   color: #f1f1f1;
# }
# #T_d98d6_row9_col1 {
#   background-color: #358bbc;
#   color: #f1f1f1;
# }
# #T_d98d6_row10_col1 {
#   background-color: #3b92b9;
#   color: #f1f1f1;
# }
# #T_d98d6_row11_col1 {
#   background-color: #47a0b3;
#   color: #f1f1f1;
# }
# #T_d98d6_row12_col1 {
#   background-color: #8cd1a4;
# ...

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Top Profitable Sub-Category:</span></li>
# <ul>
# <li ><span style="color: #808080;">Most of the sub-category products are having positive profit margin</span></li>
# <li ><span style="color: #808080;">Chairs and Tables are having negative profit margin</span></li>
# </ul>
# </ul>

# %%
# Create table based on count
order_size_counts = df['Order Size'].value_counts().sort_values(ascending=False)

# Convert to data frame for applying style
order_size_counts_df = order_size_counts.to_frame(name='Number of orders').reset_index()

# Display the output
print("Frequency of Order Sizes (Number of Products):")

# Apply background gradient
display(order_size_counts_df.style.background_gradient(cmap= "summer_r")) # Highlight cells based on values
# Out:
# Frequency of Order Sizes (Number of Products):
# <style type="text/css">
# #T_86621_row0_col0, #T_86621_row10_col1 {
#   background-color: #ffff66;
#   color: #000000;
# }
# #T_86621_row0_col1, #T_86621_row10_col0 {
#   background-color: #008066;
#   color: #f1f1f1;
# }
# #T_86621_row1_col0 {
#   background-color: #e6f266;
#   color: #000000;
# }
# #T_86621_row1_col1 {
#   background-color: #058266;
#   color: #f1f1f1;
# }
# #T_86621_row2_col0 {
#   background-color: #cce666;
#   color: #000000;
# }
# #T_86621_row2_col1 {
#   background-color: #46a266;
#   color: #f1f1f1;
# }
# #T_86621_row3_col0 {
#   background-color: #b3d966;
#   color: #000000;
# }
# #T_86621_row3_col1 {
#   background-color: #90c866;
#   color: #000000;
# }
# #T_86621_row4_col0 {
#   background-color: #99cc66;
#   color: #000000;
# }
# #T_86621_row4_col1 {
#   background-color: #b4da66;
#   color: #000000;
# }
# #T_86621_row5_col0 {
#   background-color: #7fbf66;
#   color: #000000;
# }
# #T_86621_row5_col1 {
# ...

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Frequency of Order Sizes (Number of Products):</span></li>
# <ul>
# <li ><span style="color: #808080;">Order size 1 has the highest frequency with 2,160 orders</span></li>
# <li ><span style="color: #808080;">Order size 11 has the lowest frequency with 40 orders</span></li>
# <li ><span style="color: #808080;">As order size increases, the number of orders decreases</span></li>
# </ul>
# </ul>

# %%
# Analyze orders with size 2 (2 products)
size_2_orders = df[df['Order Size'] == 2]

# Group by Order ID and create a Series with product names joined by comma
product_combos = size_2_orders.groupby('Order ID')['Category'].apply(lambda x: ','.join(x)).reset_index()

# Count occurrences of each product combination (string)
combo_counts = product_combos.groupby('Category')['Category'].count().sort_values(ascending=False)

# Convert to data frame for applying style
combo_counts_df = combo_counts.to_frame(name='Number of orders').reset_index()

# Display the output
print("\nProduct mix, Commonly purchased product combinations (Order size 2):")

# Apply background gradient
display(combo_counts_df.style.background_gradient(cmap= "Accent")) # Highlight cells based on values
# Out:
# Product mix, Commonly purchased product combinations (Order size 2):
# <style type="text/css">
# #T_04ef9_row0_col1 {
#   background-color: #666666;
#   color: #f1f1f1;
# }
# #T_04ef9_row1_col1 {
#   background-color: #386cb0;
#   color: #f1f1f1;
# }
# #T_04ef9_row2_col1 {
#   background-color: #ffff99;
#   color: #000000;
# }
# #T_04ef9_row3_col1, #T_04ef9_row4_col1, #T_04ef9_row5_col1 {
#   background-color: #7fc97f;
#   color: #000000;
# }
# </style>
# <table id="T_04ef9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_04ef9_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_04ef9_level0_col1" class="col_heading level0 col1" >Number of orders</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_04ef9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_04ef9_row0_col0" class="data row0 col0" >Office Supplies,Office Supplies</td>
# ...

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Commonly purchased product combinations (Order size 2):</span></li>
# <ul>
# <li ><span style="color: #808080;">Office Supplies with Office Supplies has highest sales combination</span></li>
# <li ><span style="color: #808080;">Office Supplies with Technology has second-highest sales combination</span></li>
# <li ><span style="color: #808080;">Furniture with Office Supplies has third-highest sales combination</span></li>
# <li ><span style="color: #808080;">Furniture with Technology, Technology with technology and Furniture with furniture has low sales combination</span></li>
# </ul>
# </ul>

# %%
# Analyze orders with size 3 (3products)
size_3_orders = df[df['Order Size'] == 3]

# Group by Order ID and create a Series with product names joined by comma
product_combos = size_3_orders.groupby('Order ID')['Category'].apply(lambda x: ','.join(x)).reset_index()

# Count occurrences of each product combination (string)
combo_counts = product_combos.groupby('Category')['Category'].count().sort_values(ascending=False)

# Convert to data frame for applying style
combo_counts_df = combo_counts.to_frame(name='Number of orders').reset_index()

# Display the output
print("\nProduct mix, Commonly purchased product combinations (Order size 3):")

# Apply background gradient
display(combo_counts_df.style.background_gradient(cmap= "Blues")) # Highlight cells based on values
# Out:
# Product mix, Commonly purchased product combinations (Order size 3):
# <style type="text/css">
# #T_49d79_row0_col1 {
#   background-color: #08306b;
#   color: #f1f1f1;
# }
# #T_49d79_row1_col1 {
#   background-color: #084184;
#   color: #f1f1f1;
# }
# #T_49d79_row2_col1 {
#   background-color: #1561a9;
#   color: #f1f1f1;
# }
# #T_49d79_row3_col1 {
#   background-color: #77b5d9;
#   color: #000000;
# }
# #T_49d79_row4_col1 {
#   background-color: #d5e5f4;
#   color: #000000;
# }
# #T_49d79_row5_col1 {
#   background-color: #d6e6f4;
#   color: #000000;
# }
# #T_49d79_row6_col1 {
#   background-color: #eff6fc;
#   color: #000000;
# }
# #T_49d79_row7_col1 {
#   background-color: #f2f8fd;
#   color: #000000;
# }
# #T_49d79_row8_col1 {
#   background-color: #f7fbff;
#   color: #000000;
# }
# </style>
# <table id="T_49d79">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_49d79_level0_col0" class="col_heading level0 col0" >Category</th>
# ...

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Commonly purchased product combinations (Order size 3):</span></li>
# <ul>
# <li ><span style="color: #808080;">Office Supplies with Office Supplies with Office Supplies has highest sales combination</span></li>
# <li ><span style="color: #808080;">Office Supplies with Office Supplies with Technology has second-highest sales combination</span></li>
# <li ><span style="color: #808080;">Furniture, Furniture, Technology and Technology, Technology, Technology combination has low sales</span></li>
# </ul>
# </ul>

# %%
# Sales by quarter

# Assign quarter labels ('Q1' - 'Q4') to DataFrame based on month using a dictionary mapping
quarter_dict = {
    1 : 'Q1', 2 : 'Q1', 3 : 'Q1',
    4 : 'Q2', 5 : 'Q2', 6 : 'Q2',
    7 : 'Q3', 8 : 'Q3', 9 : 'Q3',
    10 : 'Q4', 11 : 'Q4', 12 : 'Q4',
}

# Assign quarter labels to DataFrame based on month using a dictionary mapping
df['Quarter'] = df['Month'].map(quarter_dict)

# Perform agregation
quarter_month = (df.groupby(['Quarter'], as_index=False).agg({'Sales': 'count'}).round(2))

# Highlight cells based on values
display(quarter_month.style.background_gradient(cmap= "jet"))
# Out:
# <style type="text/css">
# #T_3ef6a_row0_col1 {
#   background-color: #000080;
#   color: #f1f1f1;
# }
# #T_3ef6a_row1_col1 {
#   background-color: #00dcfe;
#   color: #000000;
# }
# #T_3ef6a_row2_col1 {
#   background-color: #800000;
#   color: #f1f1f1;
# }
# #T_3ef6a_row3_col1 {
#   background-color: #ff5900;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_3ef6a">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3ef6a_level0_col0" class="col_heading level0 col0" >Quarter</th>
#       <th id="T_3ef6a_level0_col1" class="col_heading level0 col1" >Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3ef6a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3ef6a_row0_col0" class="data row0 col0" >Q1</td>
#       <td id="T_3ef6a_row0_col1" class="data row0 col1" >1370</td>
#     </tr>
#     <tr>
#       <th id="T_3ef6a_level0_row1" class="row_heading level0 row1" >1</th>
# ...

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Sales by quarter:</span></li>
# <ul>
# <li ><span style="color: #808080;">Q3 and Q4 contributes to most sales in year</span></li>
# </ul>
# </ul>

# %%
# Sales by weeks

# Assign week labels ('W1' - 'W5') to DataFrame based on days using a dictionary mapping
week_dict = {
    1: 'W1', 2: 'W1', 3: 'W1', 4: 'W1', 5: 'W1', 6: 'W1', 7: 'W1',
    8: 'W2', 9: 'W2', 10: 'W2', 11: 'W2', 12: 'W2', 13: 'W2', 14: 'W2',
    15: 'W3', 16: 'W3', 17: 'W3', 18: 'W3', 19: 'W3', 20: 'W3', 21: 'W3',
    22: 'W4', 23: 'W4', 24: 'W4', 25: 'W4', 26: 'W4', 27: 'W4', 28: 'W4',
    29: 'W5', 30: 'W5', 31: 'W5',
}

# Initialize 'Week' column with None values
df['Week'] = None 

# Assign week labels to DataFrame based on days using a dictionary mapping
df['Week'] = df['Day'].map(week_dict)

# Perform agregation
week_month = (df.groupby(['Week'], as_index=False).agg({'Sales': 'count'}).round(2))

# Highlight cells based on values
display(week_month.style.background_gradient(cmap= "hot"))
# Out:
# <style type="text/css">
# #T_8c3b1_row0_col1 {
#   background-color: #ffffa8;
#   color: #000000;
# }
# #T_8c3b1_row1_col1 {
#   background-color: #ffffff;
#   color: #000000;
# }
# #T_8c3b1_row2_col1 {
#   background-color: #ffffe7;
#   color: #000000;
# }
# #T_8c3b1_row3_col1 {
#   background-color: #ffffeb;
#   color: #000000;
# }
# #T_8c3b1_row4_col1 {
#   background-color: #0b0000;
#   color: #f1f1f1;
# }
# </style>
# <table id="T_8c3b1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_8c3b1_level0_col0" class="col_heading level0 col0" >Week</th>
#       <th id="T_8c3b1_level0_col1" class="col_heading level0 col1" >Sales</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8c3b1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8c3b1_row0_col0" class="data row0 col0" >W1</td>
#       <td id="T_8c3b1_row0_col1" class="data row0 col1" >1785</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# <p data-sourcepos="3:1-3:41"><strong><span style="color: #99cc00;">Interpretation:</span></strong></p>
# <ul>
# <li ><span style="color: #808080;">Sales by week:</span></li>
# <ul>
# <li ><span style="color: #808080;">W1, W2, W3 and W4 contributes to most sales in a month</span></li>
# </ul>
# </ul>

# %% [markdown]
# # <a id='toc6_'></a>[6 Summary  and Suggestions](#toc0_)

# %% [markdown]
# <p>Based on the analysis, here are my key summary and suggestions for Euromart to improve its business performance:</p>
# <p><strong>1. Identifying top performers</strong></p>
# <ul>
# <li>
# <div>
# <div><strong>Summary:</strong></div>
# </div>
# </li>
# <ul>
# <li>Regions: central region leads in sales (56%)</li>
# <li>Countries: France, Germany, the UK, Italy, and Spain have strong sales contributions</li>
# <li>States (top 10): England, france, and North Rhine-Westphalia contribute the most (66%). These states also boast positive profit margins (&gt;9.25%)</li>
# <li>Cities (top 10): London, Berlin, Vienna, Madrid, and Paris are top contributors with positive profit margins (9.8%-10.3%)</li>
# <li>Customer segments: consumers account for most sales (52%), followed by corporate and home office. Their profit margins are also positive (30-35%)</li>
# <li>Product categories: technology leads in sales (37%), followed by office supplies and furniture. Office supplies have the highest average profit margin (55%)</li>
# <li>Economy is the most used shipping mode</li>
# <li>Office supplies are dominant in the product category</li>
# </ul>
# <li><strong>Suggestions:</strong></li>
# <ul>
# <li><strong>Focus on top regions, increase marketing and promotional activities, logistics, and warehouses</strong> in France, Germany, and the UK to further boost sales</li>
# <li>Segment-specific strategies, <strong>tailor marketing strategies for the consumer segment</strong> as it represents the largest customer base</li>
# </ul>
# </ul>
# <p><strong>2. Understanding challenges</strong></p>
# <ul>
# <li><strong>Summary:</strong></li>
# <ul>
# <li>Underperforming regions/countries: Belgium, Switzerland, Denmark, Finland, Norway, and Portugal have low sales (&lt; 5%)</li>
# <li>Underperforming states: several states within these countries have low sales</li>
# <li>Low profitability: discounts above 20% lead to negative profits</li>
# <li>Uneven city coverage: some underperforming states have only one branch</li>
# <li>Negative feedback: some products receive negative feedback</li>
# <li>Low order sizes: order size 1 has the highest frequency</li>
# <li>Furniture and chairs: these categories have negative profit margins</li>
# </ul>
# <li><strong>Suggestions:</strong></li>
# <ul>
# <li><strong>Slowly expand the branches in under-performing countries</strong> to increase more reach to customers</li>
# <li><strong>Prioritize office supplies (highest profit margin) in underperforming areas</strong> to balance loss</li>
# </ul>
# </ul>
# <p><strong>3. Optimizing discounts &amp; shipping modes</strong></p>
# <ul>
# <li><strong>Summary:</strong></li>
# <ul>
# <li>Higher discounts correlate with lower profit margins</li>
# <li>Immediate shipping mode has lower discounts and higher profit margins, indicating customer willingness to pay for quick delivery</li>
# </ul>
# <li><strong>Suggestions:</strong></li>
# <ul>
# <li>Optimize discount strategy, and <strong>reduce the extent of discounts above 20% to improve profit margins</strong></li>
# <li><strong>Promote immediate shipping(Highest margins in shipping mode), highlight the benefits of immediate shipping </strong>to customers willing to pay more for faster delivery</li>
# <li><strong>Focus on promoting high-profit margin products</strong></li>
# </ul>
# </ul>
# <p><strong>4. Leveraging customer feedback&nbsp;</strong></p>
# <ul>
# <li><strong>Summary:</strong></li>
# <ul>
# <li>Almost half of the customers have provided feedback</li>
# <li>Specific products like eldon file cart and Nokia smartphone received significant feedback</li>
# </ul>
# <li><strong>Suggestions:</strong></li>
# <ul>
# <li><strong>Encourage more customers to provide feedback by offering incentives or simplifying the feedback process</strong></li>
# <li><strong>Investigate products receiving&nbsp;no feedback and take actions to get feedback to improve the customer's experience and identify potential issues faced</strong></li>
# </ul>
# </ul>
# <p><strong>5. Improving product mix</strong></p>
# <ul>
# <li><strong>Summary:</strong></li>
# <ul>
# <li>Office supplies are the most profitable category</li>
# <li>Chairs and tables have negative profit margins</li>
# <li>Order size 1 is the most common, and as order size increases, the number of orders decreases</li>
# <li>Certain product combinations are more popular than others based on order size</li>
# </ul>
# <li><strong>Suggestions:</strong></li>
# <ul>
# <li><strong>Refine product mix, focus on promoting and expanding the range of office supplies</strong></li>
# <li><strong>Re-look at the&nbsp;pricing structure of chairs and tables as they have a negative profit margin</strong></li>
# <li><strong>Encourage larger order sizes, upsell and cross-sell complementary products </strong>like office supplies with office supplies or office supplies with technology</li>
# <li><strong>Run promotions during high-selling times (Q3, Q4, first weeks of the month)</strong></li>
# </ul>
# </ul>
# <p><strong>6. Additional recommendations</strong></p>
# <ul>
# <li><strong>Data-driven decision-making,</strong> continuously monitor sales, profit margins, and customer feedback to make data-driven decisions and adjust strategies accordingly</li>
# <li><strong>Customer loyalty programs</strong>&nbsp;develop loyalty programs to <strong>reward top customers</strong> to encourage repeat purchases and enhance customer retention</li>
# <li>Efficiency improvements, <strong>streamline logistics and supply chain operations to reduce costs and improve delivery times, especially in underperforming regions</strong></li>
# </ul>
